# %% [markdown]
# # Generating the CSV

# %%
# Uninstall any old versions
# !pip uninstall enka enka-api enka-py -y

# Install the latest enka
# !pip install enka
# !pip install enkanetwork
# Now update the assets using the client
import enka
# !pip install enkanetwork.py

async def update_assets():
    async with enka.GenshinClient() as client:
        await client.update_assets()
        print("Assets updated successfully!")

await update_assets()
# Out:
# WARNING: Skipping enka as it is not installed.
# WARNING: Skipping enka-api as it is not installed.
# WARNING: Skipping enka-py as it is not installed.
# Collecting enka
#   Downloading enka-2.5.19-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: aiofiles>=24.1.0 in /usr/local/lib/python3.12/dist-packages (from enka) (24.1.0)
# Requirement already satisfied: aiohttp>=3.10.9 in /usr/local/lib/python3.12/dist-packages (from enka) (3.14.1)
# Collecting deprecated>=1.2.18 (from enka)
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting loguru>=0.7.2 (from enka)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: orjson>=3.10.7 in /usr/local/lib/python3.12/dist-packages (from enka) (3.11.9)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from enka) (2.12.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.9->enka) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.9->enka) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.9->enka) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.9->enka) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.9->enka) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.9->enka) (0.5.2)
# Requirement already satisfied: typing_extensions>=4.4 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.9->enka) (4.15.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.9->enka) (1.24.2)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated>=1.2.18->enka) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->enka) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->enka) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->enka) (0.4.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.10.9->enka) (3.18)
# Downloading enka-2.5.19-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.0/70.0 kB 4.1 MB/s eta 0:00:00
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: loguru, deprecated, enka
# Successfully installed deprecated-1.3.1 enka-2.5.19 loguru-0.7.3
# ERROR: Could not find a version that satisfies the requirement enkanetwork (from versions: none)
# ERROR: No matching distribution found for enkanetwork
# Collecting enkanetwork.py
#   Downloading enkanetwork.py-1.4.5.tar.gz (423 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.0/423.0 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from enkanetwork.py) (2.12.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from enkanetwork.py) (3.14.1)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from enkanetwork.py) (6.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->enkanetwork.py) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->enkanetwork.py) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->enkanetwork.py) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->enkanetwork.py) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->enkanetwork.py) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->enkanetwork.py) (0.5.2)
# Requirement already satisfied: typing_extensions>=4.4 in /usr/local/lib/python3.12/dist-packages (from aiohttp->enkanetwork.py) (4.15.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->enkanetwork.py) (1.24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->enkanetwork.py) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->enkanetwork.py) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->enkanetwork.py) (0.4.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp->enkanetwork.py) (3.18)
# Building wheels for collected packages: enkanetwork.py
#   Building wheel for enkanetwork.py (setup.py) ... done
#   Created wheel for enkanetwork.py: filename=enkanetwork.py-1.4.5-py3-none-any.whl size=431813 sha256=badbbddcf1822636c5f04ceb58c588c75af16fb0152919b59336e5ef0a9bf8ec
#   Stored in directory: /root/.cache/pip/wheels/8f/0c/d1/cebfa55fb8222d1997ff3f51dca8d2857bdcf2a31a7093e03c
# Successfully built enkanetwork.py
# Installing collected packages: enkanetwork.py
# Successfully installed enkanetwork.py-1.4.5
# Assets updated successfully!

# %%
import requests

def fetch_player_data(uid):
    response = requests.get(f'https://enka.network/api/uid/{uid}/')
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching data: {response.status_code}")
        return None

def count_constellations(player_data):
    # The 'talentIdList' holds the IDs of unlocked constellations.
    # A player's constellation level is the length of this list.
    if player_data and 'avatarInfoList' in player_data:
        for character in player_data['avatarInfoList']:
            # This gets the list of unlocked constellation IDs.
            talent_ids = character.get('talentIdList', [])
            const_level = len(talent_ids)
            print(f"Character {character.get('name')} has constellation level: {const_level}")
    else:
        print("No character data found.")

# Example usage with the UID from your error
uid = 618867267
player_data = fetch_player_data(uid)
count_constellations(player_data)
# Out:
# Character None has constellation level: 0
# Character None has constellation level: 0
# Character None has constellation level: 0
# Character None has constellation level: 3
# Character None has constellation level: 0
# Character None has constellation level: 0
# Character None has constellation level: 6
# Character None has constellation level: 0
# Character None has constellation level: 0
# Character None has constellation level: 0
# Character None has constellation level: 5
# Character None has constellation level: 5

# %%
import enka
import pprint

UID = 618867267

async def diagnose():
    async with enka.GenshinClient(enka.gi.Language.ENGLISH) as client:
        response = await client.fetch_showcase(UID)
        char = response.characters[0]  # first character, e.g., Ganyu
        print(f"Character: {char.name}")
        print("\n--- Attributes of 'char' ---")
        print(dir(char))
        print("\n--- char.stats ---")
        for key, stat in char.stats.items():
            print(f"  {key}: value={stat.value}, formatted={stat.formatted_value}")
        print("\n--- char.base_stats (if exists) ---")
        if hasattr(char, 'base_stats'):
            print(char.base_stats)
        else:
            print("No 'base_stats' attribute")
        print("\n--- char.character_data (if exists) ---")
        if hasattr(char, 'character_data'):
            print("character_data has:", dir(char.character_data))
            if hasattr(char.character_data, 'base_stats'):
                print("  base_stats:", char.character_data.base_stats)
        else:
            print("No 'character_data' attribute")
        print("\n--- Weapon ---")
        weapon = char.weapon
        if weapon:
            print(f"  Name: {weapon.name}")
            print("  Attributes:", dir(weapon))
            print("  weapon.stats:", weapon.stats if hasattr(weapon, 'stats') else "None")
            if hasattr(weapon, 'stats') and weapon.stats:
                for stat in weapon.stats:
                    print(f"    {stat.type}: {stat.value}")
            if hasattr(weapon, 'main_stat'):
                print(f"  weapon.main_stat: {weapon.main_stat}")
        else:
            print("No weapon")

await diagnose()
# Out:
# Character: Ganyu
#
# --- Attributes of 'char' ---
# ['__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__class_vars__', '__copy__', '__deepcopy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__fields__', '__fields_set__', '__format__', '__ge__', '__get_pydantic_core_schema__', '__get_pydantic_json_schema__', '__getattr__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__pretty__', '__private_attributes__', '__pydantic_complete__', '__pydantic_computed_fields__', '__pydantic_core_schema__', '__pydantic_custom_init__', '__pydantic_decorators__', '__pydantic_extra__', '__pydantic_fields__', '__pydantic_fields_set__', '__pydantic_generic_metadata__', '__pydantic_init_subclass__', '__pydantic_on_complete__', '__pydantic_parent_namespace__', '__pydantic_post_init__', '__pydantic_private__', '__pydantic_root_model__', '__pydantic_serializer__', '__pydantic_setattr_handlers__', '__pydantic_validator__', '__reduce__', '__reduce_ex__', '__replace__', '__repr__', '__repr_args__', '__repr_name__', '__repr_recursion__', '__repr_str__', '__rich_repr__', '__setattr__', '__setstate__', '__signature__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_calculate_keys', '_convert_constellations', '_convert_stats', '_convert_talents', '_copy_and_set_values', '_flatten_artifacts_data', '_flatten_weapon_data', '_get_value', '_intify_ascension', '_iter', '_setattr_handler', '_transform_values', 'artifacts', 'ascension', 'constellations', 'constellations_unlocked', 'construct', 'copy', 'costume', 'costume_id', 'dict', 'element', 'friendship_level', 'from_orm', 'highest_dmg_bonus_stat', 'icon', 'id', 'json', 'level', 'max_level', 'model_computed_fields', 'model_config', 'model_construct', 'model_copy', 'model_dump', 'model_dump_json', 'model_extra', 'model_fields', 'model_fields_set', 'model_json_schema', 'model_parametrized_name', 'model_post_init', 'model_rebuild', 'model_validate', 'model_validate_json', 'model_validate_strings', 'name', 'namecard', 'parse_file', 'parse_obj', 'parse_raw', 'rarity', 'schema', 'schema_json', 'skill_depot_id', 'specialized_stat', 'stats', 'talent_extra_level_map', 'talent_order', 'talents', 'update_forward_refs', 'validate', 'weapon']
#
# --- char.stats ---
#   1: value=9796.7294921875, formatted=9,797
#   2: value=5825.6298828125, formatted=5,826
#   4: value=844.4556884765625, formatted=844
#   5: value=379.0799865722656, formatted=379
#   6: value=0.9202600121498108, formatted=92.0%
#   7: value=630.214599609375, formatted=630
#   8: value=131.94000244140625, formatted=132
#   9: value=0.05829999968409538, formatted=5.8%
#   20: value=0.4311000108718872, formatted=43.1%
#   21: value=0.0, formatted=0
#   22: value=2.0576999187469482, formatted=205.8%
#   23: value=1.200700044631958, formatted=120.1%
#   26: value=0.0, formatted=0.0%
#   27: value=0.0, formatted=0
#   28: value=62.93999481201172, formatted=63
#   29: value=0.0, formatted=0
#   30: value=0.0, formatted=0.0%
#   40: value=0.0, formatted=0.0%
#   41: value=0.0, formatted=0.0%
#   42: value=0.0, formatted=0.0%
#   43: value=0.0, formatted=0.0%
#   44: value=0.0, formatted=0.0%
#   45: value=0.0, formatted=0.0%
#   46: value=0.6159999966621399, formatted=61.6%
#   50: value=0.0, formatted=0
#   51: value=0.0, formatted=0
#   52: value=0.0, formatted=0
#   53: value=0.0, formatted=0
#   54: value=0.0, formatted=0
#   55: value=0.0, formatted=0
#   56: value=0.0, formatted=0
#   75: value=60.0, formatted=60
#   1005: value=60.0, formatted=60
#   1010: value=15622.359375, formatted=15,622
#   2000: value=15622.359375, formatted=15,622
#   2001: value=2000.6544189453125, formatted=2,001
#   2002: value=798.8961181640625, formatted=799
#   2003: value=0.0, formatted=0
#   2004: value=0.0, formatted=0
#   2020: value=0.0, formatted=0
#   3045: value=0.0, formatted=0
#   3046: value=1.0, formatted=1
#
# --- char.base_stats (if exists) ---
# No 'base_stats' attribute
#
# --- char.character_data (if exists) ---
# No 'character_data' attribute
#
# --- Weapon ---
#   Name: Prototype Crescent
#   Attributes: ['__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__class_vars__', '__copy__', '__deepcopy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__fields__', '__fields_set__', '__format__', '__ge__', '__get_pydantic_core_schema__', '__get_pydantic_json_schema__', '__getattr__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__pretty__', '__private_attributes__', '__pydantic_complete__', '__pydantic_computed_fields__', '__pydantic_core_schema__', '__pydantic_custom_init__', '__pydantic_decorators__', '__pydantic_extra__', '__pydantic_fields__', '__pydantic_fields_set__', '__pydantic_generic_metadata__', '__pydantic_init_subclass__', '__pydantic_on_complete__', '__pydantic_parent_namespace__', '__pydantic_post_init__', '__pydantic_private__', '__pydantic_root_model__', '__pydantic_serializer__', '__pydantic_setattr_handlers__', '__pydantic_validator__', '__reduce__', '__reduce_ex__', '__replace__', '__repr__', '__repr_args__', '__repr_name__', '__repr_recursion__', '__repr_str__', '__rich_repr__', '__setattr__', '__setstate__', '__signature__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_calculate_keys', '_convert_icon', '_convert_stats', '_copy_and_set_values', '_extract_refinement', '_get_value', '_iter', '_setattr_handler', '_stringify_text_map_hash', 'ascension', 'construct', 'copy', 'dict', 'from_orm', 'icon', 'item_id', 'item_type', 'json', 'level', 'max_level', 'model_computed_fields', 'model_config', 'model_construct', 'model_copy', 'model_dump', 'model_dump_json', 'model_extra', 'model_fields', 'model_fields_set', 'model_json_schema', 'model_parametrized_name', 'model_post_init', 'model_rebuild', 'model_validate', 'model_validate_json', 'model_validate_strings', 'name', 'parse_file', 'parse_obj', 'parse_raw', 'rarity', 'refinement', 'schema', 'schema_json', 'stats', 'update_forward_refs', 'validate']
#   weapon.stats: [Stat(type=<StatType.FIGHT_PROP_BASE_ATTACK: 'FIGHT_PROP_BASE_ATTACK'>, value=510.0, name='Base ATK', is_percentage=False, formatted_value='510'), Stat(type=<StatType.FIGHT_PROP_ATTACK_PERCENT: 'FIGHT_PROP_ATTACK_PERCENT'>, value=41.3, name='ATK', is_percentage=True, formatted_value='41.3%')]
#     FIGHT_PROP_BASE_ATTACK: 510.0
#     FIGHT_PROP_ATTACK_PERCENT: 41.3

# %%
import enka
import csv
import os
from collections import OrderedDict, Counter

UID = 618867267
CSV_FILENAME = "genshin_data_export.csv"


def get_constellation_count(character):
    if hasattr(character, 'constellations') and character.constellations:
        try:
            if hasattr(character.constellations[0], 'activated'):
                return sum(1 for c in character.constellations if c.activated)
            elif hasattr(character.constellations[0], 'unlocked'):
                return sum(1 for c in character.constellations if c.unlocked)
        except Exception:
            pass
    if hasattr(character, 'constellations_unlocked'):
        try:
            return int(character.constellations_unlocked)
        except Exception:
            pass
    return 0


def artifact_set_bonus(artifact_set_names):
    sets = [name for name in artifact_set_names if name]
    if not sets:
        return "None"
    counter = Counter(sets)
    bonuses = []
    for set_name, count in counter.items():
        if count >= 4:
            bonuses.append(f"{set_name} x4")
        elif count >= 2:
            bonuses.append(f"{set_name} x2")
    return " + ".join(bonuses) if bonuses else "None"


async def main():
    async with enka.GenshinClient(enka.gi.Language.ENGLISH) as client:
        response = await client.fetch_showcase(UID)

        header = [
            "UID", "Player Nickname", "Player Level", "Player Signature",
            "Character Name", "Character Level", "Character Ascension",
            "Character Friendship", "Character Constellations",
            "Weapon Name", "Weapon Level", "Weapon Ascension",
            "Weapon Refinement", "Weapon Stars",
            "Talent NA Level", "Talent Skill Level", "Talent Burst Level",
        ]

        stat_map = {
            enka.gi.FightPropType.FIGHT_PROP_HP: "HP",
            enka.gi.FightPropType.FIGHT_PROP_ATTACK: "ATK",
            enka.gi.FightPropType.FIGHT_PROP_DEFENSE: "DEF",
            enka.gi.FightPropType.FIGHT_PROP_CRITICAL: "Crit Rate",
            enka.gi.FightPropType.FIGHT_PROP_CRITICAL_HURT: "Crit DMG",
            enka.gi.FightPropType.FIGHT_PROP_CHARGE_EFFICIENCY: "Energy Recharge",
            enka.gi.FightPropType.FIGHT_PROP_ELEMENT_MASTERY: "Elemental Mastery",
            enka.gi.FightPropType.FIGHT_PROP_HEAL_ADD: "Healing Bonus",
            enka.gi.FightPropType.FIGHT_PROP_PHYSICAL_ADD_HURT: "Physical DMG Bonus",
            enka.gi.FightPropType.FIGHT_PROP_FIRE_ADD_HURT: "Pyro DMG Bonus",
            enka.gi.FightPropType.FIGHT_PROP_WATER_ADD_HURT: "Hydro DMG Bonus",
            enka.gi.FightPropType.FIGHT_PROP_WIND_ADD_HURT: "Anemo DMG Bonus",
            enka.gi.FightPropType.FIGHT_PROP_ICE_ADD_HURT: "Cryo DMG Bonus",
            enka.gi.FightPropType.FIGHT_PROP_ELEC_ADD_HURT: "Electro DMG Bonus",
            enka.gi.FightPropType.FIGHT_PROP_GRASS_ADD_HURT: "Dendro DMG Bonus",
        }
        for stat_name in stat_map.values():
            header.append(stat_name)

        header.append("Artifact Set Bonus")
        for i in range(5):
            header.extend([
                f"Artifact {i+1} Set", f"Artifact {i+1} Name",
                f"Artifact {i+1} Main Stat Type", f"Artifact {i+1} Main Stat Value",
                f"Artifact {i+1} Sub 1", f"Artifact {i+1} Sub 2",
                f"Artifact {i+1} Sub 3", f"Artifact {i+1} Sub 4",
            ])

        data = OrderedDict()
        if os.path.exists(CSV_FILENAME):
            with open(CSV_FILENAME, "r", encoding="utf-8") as f:
                reader = csv.reader(f)
                existing_header = next(reader, None)
                if existing_header == header:
                    for row in reader:
                        key = (row[0], row[4])
                        data[key] = row
                else:
                    print("Header mismatch – starting fresh.")
        else:
            print("No existing file – creating new.")

        # --- Special numeric keys for final HP/ATK/DEF ---
        # These are the keys that hold the fully calculated totals (base + weapon + artifacts)
        FINAL_STAT_KEYS = {
            enka.gi.FightPropType.FIGHT_PROP_HP: 2000,
            enka.gi.FightPropType.FIGHT_PROP_ATTACK: 2001,
            enka.gi.FightPropType.FIGHT_PROP_DEFENSE: 2002,
        }

        for character in response.characters:
            char_name = character.name
            char_level = character.level
            char_ascension = character.ascension
            char_friendship = character.friendship_level
            char_constellations = get_constellation_count(character)

            weapon = character.weapon
            if weapon:
                weapon_name = weapon.name
                weapon_level = weapon.level
                weapon_ascension = weapon.ascension
                weapon_refinement = weapon.refinement
                weapon_stars = weapon.rarity
            else:
                weapon_name = weapon_level = weapon_ascension = weapon_refinement = weapon_stars = ""

            talents = character.talents
            talent_na = talents[0].level if len(talents) > 0 else ""
            talent_skill = talents[1].level if len(talents) > 1 else ""
            talent_burst = talents[2].level if len(talents) > 2 else ""

            row = [
                str(UID),
                response.player.nickname,
                response.player.level,
                response.player.signature,
                char_name,
                char_level,
                char_ascension,
                char_friendship,
                char_constellations,
                weapon_name,
                weapon_level,
                weapon_ascension,
                weapon_refinement,
                weapon_stars,
                talent_na,
                talent_skill,
                talent_burst,
            ]

            # --- Stats extraction ---
            for prop_type in stat_map.keys():
                if prop_type in (enka.gi.FightPropType.FIGHT_PROP_HP,
                                 enka.gi.FightPropType.FIGHT_PROP_ATTACK,
                                 enka.gi.FightPropType.FIGHT_PROP_DEFENSE):
                    # Use the special numeric keys that hold final totals
                    special_key = FINAL_STAT_KEYS.get(prop_type)
                    stat_obj = character.stats.get(special_key)
                    if stat_obj:
                        val = stat_obj.value
                    else:
                        # fallback to the normal key if special key missing
                        stat_obj = character.stats.get(prop_type)
                        val = stat_obj.value if stat_obj else 0.0
                    row.append(str(val))
                else:
                    stat_obj = character.stats.get(prop_type)
                    row.append(stat_obj.formatted_value if stat_obj else "")

            # --- Artifact processing ---
            artifacts = list(character.artifacts) + [None] * (5 - len(character.artifacts))
            artifact_set_names = []
            artifact_details = []

            for artifact in artifacts:
                if artifact:
                    set_name = artifact.set_name
                    artifact_name = artifact.name
                    main_stat_type = artifact.main_stat.type.name
                    main_stat_value = artifact.main_stat.value
                    subs = []
                    for sub in artifact.sub_stats[:4]:
                        subs.append(f"{sub.type.name}+{sub.value}")
                    subs += [""] * (4 - len(subs))
                else:
                    set_name = artifact_name = ""
                    main_stat_type = main_stat_value = ""
                    subs = ["", "", "", ""]
                artifact_set_names.append(set_name)
                artifact_details.append([set_name, artifact_name, main_stat_type, main_stat_value] + subs)

            set_bonus = artifact_set_bonus(artifact_set_names)
            row.append(set_bonus)

            for details in artifact_details:
                row.extend(details)

            if len(row) < len(header):
                row += [""] * (len(header) - len(row))
            else:
                row = row[:len(header)]

            key = (str(UID), char_name)
            data[key] = row
            print(f"  Processed: {char_name} (C{char_constellations}) – {set_bonus}")

        with open(CSV_FILENAME, "w", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow(header)
            writer.writerows(data.values())

        print(f"\n✅ Data updated for UID {UID}.")
        print(f"   Total characters stored: {len(data)}")
        print(f"   File saved as: {CSV_FILENAME}")

await main()
# Out:
#   Processed: Ganyu (C0) – Blizzard Strayer x4
#   Processed: Raiden Shogun (C0) – Emblem of Severed Fate x4
#   Processed: Skirk (C0) – Finale of the Deep Galleries x2
#   Processed: Neuvillette (C0) – Marechaussee Hunter x4
#   Processed: Xiangling (C3) – Emblem of Severed Fate x4
#   Processed: Venti (C0) – Viridescent Venerer x4
#   Processed: Kinich (C0) – Obsidian Codex x4
#   Processed: Rosaria (C0) – Blizzard Strayer x4
#   Processed: Nicole (C0) – Celestial Gift x4
#   Processed: Durin (C0) – A Day Carved From Rising Winds x4
#   Processed: Xingqiu (C5) – Emblem of Severed Fate x4
#   Processed: Bennett (C5) – Noblesse Oblige x4
#
# ✅ Data updated for UID 618867267.
#    Total characters stored: 46
#    File saved as: genshin_data_export.csv

# %% [markdown]
# # GCSim CLI

# %%
# Download the Linux executable directly (no .tar.gz extension)
# !wget https://github.com/genshinsim/gcsim/releases/download/v2.42.2/gcsim_linux_amd64

# Make it executable
# !chmod +x gcsim_linux_amd64

# (Optional) Rename to just 'gcsim' for convenience
# !mv gcsim_linux_amd64 gcsim
# Out:
# --2026-06-18 14:03:42--  https://github.com/genshinsim/gcsim/releases/download/v2.42.2/gcsim_linux_amd64
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/376835082/8f9592f1-48df-4f20-925e-656c7aa67b2e?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-06-18T15%3A03%3A22Z&rscd=attachment%3B+filename%3Dgcsim_linux_amd64&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-06-18T14%3A02%3A35Z&ske=2026-06-18T15%3A03%3A22Z&sks=b&skv=2018-11-09&sig=rS4FEKWotBxlAgi6pJpFYgbC0NQ69gvxVk5BbJH9p64%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4MTc5MzIyMiwibmJmIjoxNzgxNzkxNDIyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.mYCJzrF6N9cZFVMid_KiE6WQkISJh5j7niejrknbi6A&response-content-disposition=attachment%3B%20filename%3Dgcsim_linux_amd64&response-content-type=application%2Foctet-stream [following]
# --2026-06-18 14:03:42--  https://release-assets.githubusercontent.com/github-production-release-asset/376835082/8f9592f1-48df-4f20-925e-656c7aa67b2e?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-06-18T15%3A03%3A22Z&rscd=attachment%3B+filename%3Dgcsim_linux_amd64&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-06-18T14%3A02%3A35Z&ske=2026-06-18T15%3A03%3A22Z&sks=b&skv=2018-11-09&sig=rS4FEKWotBxlAgi6pJpFYgbC0NQ69gvxVk5BbJH9p64%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4MTc5MzIyMiwibmJmIjoxNzgxNzkxNDIyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.mYCJzrF6N9cZFVMid_KiE6WQkISJh5j7niejrknbi6A&response-content-disposition=attachment%3B%20filename%3Dgcsim_linux_amd64&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34862578 (33M) [application/octet-stream]
# Saving to: ‘gcsim_linux_amd64’
#
# gcsim_linux_amd64   100%[===================>]  33.25M   102MB/s    in 0.3s
#
# 2026-06-18 14:03:42 (102 MB/s) - ‘gcsim_linux_amd64’ saved [34862578/34862578]

# %%
# !./gcsim -h
# Out:
# Usage of ./gcsim:
#   -c string
#     	which profile to use (default "config.txt")
#   -cpuprofile string
#     	write cpu profile to a file. supply file path (otherwise empty string for disabled).
#     	can be viewed in the browser via "go tool pprof -http=localhost:3000 cpu.prof" (insert your desired host/port/filename, requires Graphviz)
#   -gz
#     	gzip json results; require out flag
#   -ks
#     	keep serving same results without terminating web server
#   -memprofile string
#     	write memory profile to a file. supply file path (otherwise empty string for disabled).
#     	can be viewed in the browser via "go tool pprof -http=localhost:3000 mem.prof" (insert your desired host/port/filename, requires Graphviz)
#   -nb
#     	disable opening default browser
#   -nr
#     	disable running the simulation (useful if you only want to generate a sample
#   -options string
#     	Additional options for substat optimization mode. Currently supports the following flags, set in a semi-colon delimited list (e.g. -options="total_liquid_substats=15;indiv_liquid_cap=8"):
#     	- total_liquid_substats (default = 20): Total liquid substats available to be assigned across all substats
#     	- indiv_liquid_cap (default = 10): Total liquid substats that can be assigned to a single substat
#     	- fixed_substats_count (default = 2): Amount of fixed substats that are assigned to all substats
#     	- fine_tune (default = 1): Set to 0 to disable fine tune step of substat optimizer.
#     	- show_substat_scalars (default = 1): Set to 0 to disable formatting substats by their scalars in the resulting config.
#   -out string
#     	output result to file? supply file path (otherwise empty string for disabled). default disabled
#   -s	serve results to viewer (local). default false
#   -sample string
#     	create sample result. supply file path (otherwise empty string for disabled). default disabled
#   -sampleMaxDps string
#     	create sample result for the max-DPS run. supply file path (otherwise empty string for disabled). default disabled
#   -sampleMinDps string
#     	create sample result for the min-DPS run. supply file path (otherwise empty string for disabled). default disabled
#   -substatOptim
#     	Optimize substats according to KQM standards. Set the out flag to output config with optimal substats inserted to a given file path. Alternatively use the substatOptimFull flag to avoid a second config file and second invocation of the sim.
#   -substatOptimFull
#     	Optimize substats according to KQM standards, overwrite the given config with the optimized version and then run the sim on it. Set the out flag and gz flag to save the viewer file. substatOptim flag takes precedence over this flag, so do not use them together.
#   -update
#     	run autoupdater (default: false)
#   -v	Verbose output log (currently only for substat optimization)
#   -version
#     	check gcsim version (git hash)

# %% [markdown]
# # GCSim Pareto

# %%
# Out:
# Loaded 35 usable character(s): ['aetherdendro', 'ayato', 'barbara', 'beidou', 'bennett', 'charlotte', 'chevreuse', 'chongyun', 'citlali', 'collei', 'diona', 'fischl', 'furina', 'ganyu', 'heizou', 'jean', 'kinich', 'kuki', 'mavuika', 'mona', 'navia', 'neuvillette', 'ningguang', 'raiden', 'rosaria', 'sara', 'skirk', 'sucrose', 'venti', 'wriothesley', 'xiangling', 'xingqiu', 'yanfei', 'yelan', 'yunjin']
#
# Skipped 3 character(s) gcsim doesn't support yet:
#   - Nicole
#   - Durin
#   - Iansan
#
# 7 note(s)/warning(s):
#   - SKIPPED character 'Nicole': not in gcsim.
#   - SKIPPED character 'Durin': not in gcsim.
#   - Xingqiu -> xingqiu: Skill boosted by C3, base 8.
#   - Bennett -> bennett: Burst boosted by C5, base 8.
#   - Diona -> diona: Skill boosted by C3, base 8.
#   - SKIPPED character 'Iansan': not in gcsim.
#   - Aether: auto-detected 'dendro' from goblet.
#
# Output folder: optimizer_results/general_20260617_213611
# Starting EA: pop=2000, gen=50, duration=90s, iterations=10, mode=Pareto multi‑objective
# Debug team DPS: 8778, max_hit: 40333
#
# Generation 1/50
# Unique individuals: 2000/2000
# Top 5 this gen:
#   [support_first] start:furina team:['ganyu', 'mavuika', 'bennett', 'furina'] DPS:31677 MaxHit:191904
#   [battery_first] start:sucrose team:['sucrose', 'jean', 'furina', 'fischl'] DPS:31453 MaxHit:80086
#   [battery_first] start:furina team:['mavuika', 'rosaria', 'raiden', 'furina'] DPS:28551 MaxHit:150669
#   [standard] start:fischl team:['furina', 'collei', 'fischl', 'mavuika'] DPS:26691 MaxHit:112618
#   [battery_first] start:mavuika team:['mavuika', 'xingqiu', 'fischl', 'yanfei'] DPS:26677 MaxHit:147980
# Gen best: (1, 3, 'ganyu', 'mavuika', 'bennett', 'furina') DPS:31677 MaxHit:191904
# Overall best: (1, 3, 'ganyu', 'mavuika', 'bennett', 'furina') DPS:31677 MaxHit:191904
#
# Generation 2/50
# Unique individuals: 1868/2000
# Top 5 this gen:
#   [burst_skill_weave] start:mavuika team:['ganyu', 'mavuika', 'citlali', 'bennett'] DPS:36675 MaxHit:413130
#   [burst_skill_weave] start:neuvillette team:['neuvillette', 'xiangling', 'fischl', 'furina'] DPS:34283 MaxHit:92205
#   [support_first] start:mavuika team:['neuvillette', 'mavuika', 'kuki', 'furina'] DPS:33394 MaxHit:120724
#   [support_first] start:furina team:['ganyu', 'mavuika', 'bennett', 'furina'] DPS:32651 MaxHit:203771
#   [battery_first] start:sucrose team:['sucrose', 'jean', 'furina', 'fischl'] DPS:32649 MaxHit:71691
# Gen best: (7, 1, 'ganyu', 'mavuika', 'citlali', 'bennett') DPS:36675 MaxHit:413130
# Overall best: (7, 1, 'ganyu', 'mavuika', 'citlali', 'bennett') DPS:36675 MaxHit:413130
#
# Generation 3/50
# Unique individuals: 1834/2000
# Top 5 this gen:
#   [burst_skill_weave] start:neuvillette team:['neuvillette', 'sucrose', 'fischl', 'furina'] DPS:40408 MaxHit:91580
#   [burst_skill_weave] start:mavuika team:['ganyu', 'mavuika', 'citlali', 'bennett'] DPS:36498 MaxHit:410556
#   [burst_skill_weave] start:neuvillette team:['neuvillette', 'raiden', 'citlali', 'furina'] DPS:36423 MaxHit:90867
#   [burst_skill_weave] start:neuvillette team:['neuvillette', 'xiangling', 'fischl', 'furina'] DPS:35506 MaxHit:80483
#   [burst_skill_weave] start:bennett team:['ganyu', 'mavuika', 'furina', 'bennett'] DPS:35159 MaxHit:185876
# Gen best: (7, 0, 'neuvillette', 'sucrose', 'fischl', 'furina') DPS:40408 MaxHit:91580
# Overall best: (7, 0, 'neuvillette', 'sucrose', 'fischl', 'furina') DPS:40408 MaxHit:91580
#
# Generation 4/50
# Unique individuals: 1798/2000
# Top 5 this gen:
#   [quickswap] start:furina team:['neuvillette', 'mavuika', 'fischl', 'furina'] DPS:39853 MaxHit:123080
#   [burst_skill_weave] start:neuvillette team:['neuvillette', 'sucrose', 'fischl', 'furina'] DPS:39818 MaxHit:95257
#   [burst_skill_weave] start:fischl team:['neuvillette', 'sucrose', 'fischl', 'furina'] DPS:38899 MaxHit:96744
#   [burst_skill_weave] start:mavuika team:['ganyu', 'mavuika', 'citlali', 'bennett'] DPS:38308 MaxHit:402155
#   [standard] start:furina team:['mavuika', 'sucrose', 'furina', 'fischl'] DPS:38112 MaxHit:237710
# Gen best: (2, 3, 'neuvillette', 'mavuika', 'fischl', 'furina') DPS:39853 MaxHit:123080
# Overall best: (7, 0, 'neuvillette', 'sucrose', 'fischl', 'furina') DPS:40408 MaxHit:91580
#
# Generation 5/50
# Unique individuals: 1815/2000
# Top 5 this gen:
#   [battery_first] start:furina team:['neuvillette', 'furina', 'mavuika', 'fischl'] DPS:42118 MaxHit:131438
#   [battery_first] start:neuvillette team:['neuvillette', 'furina', 'mavuika', 'fischl'] DPS:42100 MaxHit:128219
#   [quickswap] start:neuvillette team:['neuvillette', 'jean', 'furina', 'fischl'] DPS:41277 MaxHit:102069
#   [quickswap] start:furina team:['neuvillette', 'mavuika', 'fischl', 'furina'] DPS:39842 MaxHit:123790
#   [burst_skill_weave] start:fischl team:['neuvillette', 'sucrose', 'fischl', 'furina'] DPS:39256 MaxHit:88594
# Gen best: (11, 1, 'neuvillette', 'furina', 'mavuika', 'fischl') DPS:42118 MaxHit:131438
# Overall best: (11, 1, 'neuvillette', 'furina', 'mavuika', 'fischl') DPS:42118 MaxHit:131438
#
# Generation 6/50
# Unique individuals: 1781/2000
# Top 5 this gen:
#   [quickswap] start:neuvillette team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:43722 MaxHit:165093
#   [battery_first] start:neuvillette team:['neuvillette', 'furina', 'mavuika', 'fischl'] DPS:43194 MaxHit:152455
#   [battery_first] start:neuvillette team:['neuvillette', 'furina', 'mavuika', 'fischl'] DPS:42890 MaxHit:150743
#   [battery_first] start:furina team:['neuvillette', 'furina', 'mavuika', 'fischl'] DPS:42054 MaxHit:158259
#   [quickswap] start:furina team:['neuvillette', 'furina', 'fischl', 'citlali'] DPS:42015 MaxHit:80553
# Gen best: (2, 0, 'neuvillette', 'mavuika', 'furina', 'citlali') DPS:43722 MaxHit:165093
# Overall best: (2, 0, 'neuvillette', 'mavuika', 'furina', 'citlali') DPS:43722 MaxHit:165093
#
# Generation 7/50
# Unique individuals: 1756/2000
# Top 5 this gen:
#   [battery_first] start:neuvillette team:['neuvillette', 'furina', 'mavuika', 'fischl'] DPS:43178 MaxHit:147792
#   [quickswap] start:neuvillette team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:43158 MaxHit:193726
#   [quickswap] start:furina team:['neuvillette', 'furina', 'fischl', 'citlali'] DPS:43048 MaxHit:90959
#   [quickswap] start:mavuika team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:42725 MaxHit:199362
#   [battery_first] start:neuvillette team:['neuvillette', 'furina', 'mavuika', 'fischl'] DPS:42717 MaxHit:151599
# Gen best: (11, 0, 'neuvillette', 'furina', 'mavuika', 'fischl') DPS:43178 MaxHit:147792
# Overall best: (2, 0, 'neuvillette', 'mavuika', 'furina', 'citlali') DPS:43722 MaxHit:165093
#
# Generation 8/50
# Unique individuals: 1705/2000
# Top 5 this gen:
#   [quickswap] start:mavuika team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:44329 MaxHit:192942
#   [quickswap] start:mavuika team:['neuvillette', 'citlali', 'furina', 'mavuika'] DPS:44325 MaxHit:191247
#   [quickswap] start:mavuika team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:43897 MaxHit:213466
#   [quickswap] start:neuvillette team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:43657 MaxHit:169292
#   [quickswap] start:mavuika team:['neuvillette', 'citlali', 'furina', 'mavuika'] DPS:42979 MaxHit:191485
# Gen best: (2, 1, 'neuvillette', 'mavuika', 'furina', 'citlali') DPS:44329 MaxHit:192942
# Overall best: (2, 1, 'neuvillette', 'mavuika', 'furina', 'citlali') DPS:44329 MaxHit:192942
#
# Generation 9/50
# Unique individuals: 1597/2000
# Top 5 this gen:
#   [battery_first] start:citlali team:['neuvillette', 'mavuika', 'citlali', 'furina'] DPS:44186 MaxHit:193150
#   [quickswap] start:neuvillette team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:43936 MaxHit:167042
#   [quickswap] start:mavuika team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:43822 MaxHit:185889
#   [battery_first] start:neuvillette team:['neuvillette', 'mavuika', 'citlali', 'furina'] DPS:43774 MaxHit:157953
#   [quickswap] start:mavuika team:['neuvillette', 'citlali', 'furina', 'mavuika'] DPS:43685 MaxHit:197785
# Gen best: (11, 2, 'neuvillette', 'mavuika', 'citlali', 'furina') DPS:44186 MaxHit:193150
# Overall best: (2, 1, 'neuvillette', 'mavuika', 'furina', 'citlali') DPS:44329 MaxHit:192942
#
# Generation 10/50
# Unique individuals: 1456/2000
# Top 5 this gen:
#   [quickswap] start:mavuika team:['neuvillette', 'citlali', 'furina', 'mavuika'] DPS:44512 MaxHit:191717
#   [quickswap] start:citlali team:['neuvillette', 'mavuika', 'citlali', 'furina'] DPS:44214 MaxHit:193150
#   [quickswap] start:furina team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:44194 MaxHit:192587
#   [quickswap] start:furina team:['neuvillette', 'mavuika', 'citlali', 'furina'] DPS:43983 MaxHit:193150
#   [quickswap] start:furina team:['neuvillette', 'mavuika', 'citlali', 'furina'] DPS:43974 MaxHit:193150
# Gen best: (2, 3, 'neuvillette', 'citlali', 'furina', 'mavuika') DPS:44512 MaxHit:191717
# Overall best: (2, 3, 'neuvillette', 'citlali', 'furina', 'mavuika') DPS:44512 MaxHit:191717
#
# Generation 11/50
# Unique individuals: 1328/2000
# Top 5 this gen:
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45137 MaxHit:231562
#   [quickswap] start:furina team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:44944 MaxHit:213466
#   [quickswap] start:mavuika team:['neuvillette', 'citlali', 'furina', 'mavuika'] DPS:44889 MaxHit:197785
#   [battery_first] start:citlali team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:44644 MaxHit:190489
#   [quickswap] start:citlali team:['neuvillette', 'mavuika', 'citlali', 'furina'] DPS:44532 MaxHit:193150
# Gen best: (11, 3, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:45137 MaxHit:231562
# Overall best: (11, 3, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:45137 MaxHit:231562
#
# Generation 12/50
# Unique individuals: 1192/2000
# Top 5 this gen:
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45236 MaxHit:221581
#   [quickswap] start:mavuika team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:44745 MaxHit:195991
#   [quickswap] start:mavuika team:['neuvillette', 'mavuika', 'citlali', 'furina'] DPS:44703 MaxHit:175540
#   [quickswap] start:mavuika team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:44622 MaxHit:211949
#   [battery_first] start:furina team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:44596 MaxHit:195991
# Gen best: (11, 3, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:45236 MaxHit:221581
# Overall best: (11, 3, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:45236 MaxHit:221581
#
# Generation 13/50
# Unique individuals: 1054/2000
# Top 5 this gen:
#   [quickswap] start:citlali team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45230 MaxHit:221581
#   [quickswap] start:mavuika team:['neuvillette', 'citlali', 'mavuika', 'furina'] DPS:45169 MaxHit:218638
#   [battery_first] start:citlali team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:45112 MaxHit:185889
#   [quickswap] start:mavuika team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:44906 MaxHit:195991
#   [battery_first] start:furina team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:44770 MaxHit:184689
# Gen best: (2, 2, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:45230 MaxHit:221581
# Overall best: (11, 3, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:45236 MaxHit:221581
#
# Generation 14/50
# Unique individuals: 979/2000
# Top 5 this gen:
#   [quickswap] start:furina team:['neuvillette', 'citlali', 'mavuika', 'furina'] DPS:45650 MaxHit:256231
#   [quickswap] start:citlali team:['neuvillette', 'mavuika', 'citlali', 'furina'] DPS:45114 MaxHit:193150
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45084 MaxHit:208891
#   [battery_first] start:neuvillette team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45050 MaxHit:209910
#   [quickswap] start:furina team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:45024 MaxHit:185889
# Gen best: (2, 3, 'neuvillette', 'citlali', 'mavuika', 'furina') DPS:45650 MaxHit:256231
# Overall best: (2, 3, 'neuvillette', 'citlali', 'mavuika', 'furina') DPS:45650 MaxHit:256231
#
# Generation 15/50
# Unique individuals: 890/2000
# Top 5 this gen:
#   [quickswap] start:furina team:['neuvillette', 'citlali', 'mavuika', 'furina'] DPS:45919 MaxHit:214920
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45529 MaxHit:236525
#   [quickswap] start:furina team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:45384 MaxHit:185889
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45297 MaxHit:230689
#   [quickswap] start:mavuika team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:45236 MaxHit:179797
# Gen best: (2, 3, 'neuvillette', 'citlali', 'mavuika', 'furina') DPS:45919 MaxHit:214920
# Overall best: (2, 3, 'neuvillette', 'citlali', 'mavuika', 'furina') DPS:45919 MaxHit:214920
#
# Generation 16/50
# Unique individuals: 847/2000
# Top 5 this gen:
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:46079 MaxHit:238841
#   [quickswap] start:furina team:['neuvillette', 'citlali', 'mavuika', 'furina'] DPS:45941 MaxHit:224237
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45632 MaxHit:232271
#   [battery_first] start:citlali team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45464 MaxHit:231562
#   [quickswap] start:furina team:['neuvillette', 'citlali', 'mavuika', 'furina'] DPS:45386 MaxHit:229198
# Gen best: (11, 3, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46079 MaxHit:238841
# Overall best: (11, 3, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46079 MaxHit:238841
#
# Generation 17/50
# Unique individuals: 843/2000
# Top 5 this gen:
#   [quickswap] start:citlali team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:46371 MaxHit:232304
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45798 MaxHit:198445
#   [quickswap] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45785 MaxHit:232271
#   [quickswap] start:furina team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:45772 MaxHit:195991
#   [battery_first] start:furina team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45506 MaxHit:221581
# Gen best: (2, 2, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46371 MaxHit:232304
# Overall best: (2, 2, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46371 MaxHit:232304
#
# Generation 18/50
# Unique individuals: 872/2000
# Top 5 this gen:
#   [battery_first] start:neuvillette team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45926 MaxHit:220488
#   [quickswap] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45681 MaxHit:236525
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45605 MaxHit:221581
#   [battery_first] start:neuvillette team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45557 MaxHit:220488
#   [quickswap] start:furina team:['neuvillette', 'citlali', 'mavuika', 'furina'] DPS:45557 MaxHit:249228
# Gen best: (11, 0, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:45926 MaxHit:220488
# Overall best: (2, 2, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46371 MaxHit:232304
#
# Generation 19/50
# Unique individuals: 903/2000
# Top 5 this gen:
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:46172 MaxHit:232980
#   [quickswap] start:citlali team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:46111 MaxHit:232271
#   [battery_first] start:furina team:['neuvillette', 'citlali', 'mavuika', 'furina'] DPS:46017 MaxHit:215432
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45927 MaxHit:232271
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45881 MaxHit:230095
# Gen best: (11, 3, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46172 MaxHit:232980
# Overall best: (2, 2, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46371 MaxHit:232304
#
# Generation 20/50
# Unique individuals: 867/2000
# Top 5 this gen:
#   [quickswap] start:furina team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:46589 MaxHit:232980
#   [battery_first] start:citlali team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:46498 MaxHit:198877
#   [quickswap] start:citlali team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45999 MaxHit:232271
#   [quickswap] start:furina team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45950 MaxHit:238841
#   [battery_first] start:neuvillette team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45827 MaxHit:220493
# Gen best: (2, 1, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46589 MaxHit:232980
# Overall best: (2, 1, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46589 MaxHit:232980
#
# Generation 21/50
# Unique individuals: 754/2000
# Top 5 this gen:
#   [battery_first] start:citlali team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:46072 MaxHit:231562
#   [battery_first] start:citlali team:['neuvillette', 'citlali', 'mavuika', 'furina'] DPS:45948 MaxHit:256231
#   [battery_first] start:furina team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45920 MaxHit:238628
#   [battery_first] start:citlali team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45906 MaxHit:236517
#   [quickswap] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45881 MaxHit:198445
# Gen best: (11, 2, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46072 MaxHit:231562
# Overall best: (2, 1, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46589 MaxHit:232980
#
# Generation 22/50
#
# Interrupted! Saving best so far.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_713/2962276015.py in <cell line: 0>()
#     825 if __name__ == "__main__":
#     826     # Example 1: multi‑objective (Pareto) – you get best DPS + nuke + consistent teams
# --> 827     run_optimizer(
#     828         #lock_chars=["ganyu"],
#     829         csv_path="genshin_data_export.csv",
#
# /tmp/ipykernel_713/2962276015.py in run_optimizer(lock_chars, csv_path, gcsim_bin, sim_duration, sim_iterations, population_size, generations, mutation_rate, crossover_rate, tournament_size, min_character_level, traveler_override, traveler_default, save_prefix, pareto)
#     724         for gen in range(generations):
#     725             print(f"\nGeneration {gen+1}/{generations}")
# --> 726             scores = [fitness(ind) for ind in population]
#     727             unique_teams = set(population)
#     728             print(f"Unique individuals: {len(unique_teams)}/{population_size}")
#
# /tmp/ipykernel_713/2962276015.py in fitness(team)
#     591     def fitness(team):
#     592         config = build_full_config(team)
# --> 593         return run_gcsim(config)
#     594
#     595     def tournament_selection(population, scores):
#
# /tmp/ipykernel_713/2962276015.py in run_gcsim(config_str)
#     541         output_path = config_path + '.json'
#     542         try:
# --> 543             result = subprocess.run(
#     544                 [gcsim_bin, '-c', config_path, '-out', output_path],
#     545                 capture_output=True, text=True, timeout=120
#
# /usr/lib/python3.12/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548     with Popen(*popenargs, **kwargs) as process:
#     549         try:
# --> 550             stdout, stderr = process.communicate(input, timeout=timeout)
#     551         except TimeoutExpired as exc:
#     552             process.kill()
#
# /usr/lib/python3.12/subprocess.py in communicate(self, input, timeout)
#    1207
#    1208             try:
# -> 1209                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1210             except KeyboardInterrupt:
#    1211                 # https://bugs.python.org/issue25942
#
# /usr/lib/python3.12/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    2113                             'failed to raise TimeoutExpired.')
#    2114
# -> 2115                     ready = selector.select(timeout)
#    2116                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2117
#
# /usr/lib/python3.12/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
import pandas as pd
import subprocess
import json
import random
import re
import tempfile
import os
from datetime import datetime

# -----------------------------------------------------------------
#  Parameterised run function – call this with your custom settings!
# -----------------------------------------------------------------
def run_optimizer(
    lock_chars=None,
    csv_path="genshin_data_export.csv",
    gcsim_bin="./gcsim",
    sim_duration=20,
    sim_iterations=150,
    population_size=100,
    generations=40,
    mutation_rate=0.15,
    crossover_rate=0.8,
    tournament_size=3,
    min_character_level=50,
    traveler_override=None,
    traveler_default="anemo",
    save_prefix="default",
    pareto=True               # Set to False for pure DPS optimisation (no Pareto archive)
):
    # ---- Canonical gcsim data (kept inside to avoid global clutter) ----
    GCSIM_CHARACTER_KEYS = {
        'aino', 'albedo', 'alhaitham', 'aloy', 'amber', 'arlecchino', 'ayaka', 'ayato',
        'baizhu', 'barbara', 'beidou', 'bennett', 'candace', 'charlotte', 'chasca',
        'chevreuse', 'chiori', 'chongyun', 'citlali', 'clorinde', 'collei', 'columbina',
        'cyno', 'dahlia', 'dehya', 'diluc', 'diona', 'dori', 'emilie', 'escoffier', 'eula',
        'faruzan', 'fischl', 'flins', 'freminet', 'furina', 'gaming', 'ganyu', 'gorou',
        'heizou', 'hutao', 'ineffa', 'itto', 'jean', 'kaeya', 'kaveh', 'kazuha', 'keqing',
        'kinich', 'kirara', 'klee', 'kokomi', 'kuki', 'lanyan', 'lauma', 'layla', 'lisa',
        'lynette', 'lyney', 'mavuika', 'mika', 'mizuki', 'mona', 'mualani', 'nahida',
        'navia', 'neuvillette', 'nilou', 'ningguang', 'noelle', 'ororon', 'qiqi', 'raiden',
        'razor', 'rosaria', 'sara', 'sayu', 'sethos', 'shenhe', 'sigewinne', 'skirk',
        'sucrose', 'tartaglia', 'thoma', 'tighnari', 'varesa', 'venti', 'wanderer',
        'wriothesley', 'xiangling', 'xianyun', 'xiao', 'xilonen', 'xingqiu', 'xinyan',
        'yaemiko', 'yanfei', 'yaoyao', 'yelan', 'yoimiya', 'yunjin', 'zhongli',
    }
    TRAVELER_ELEMENTS = ('anemo', 'geo', 'electro', 'dendro', 'hydro', 'pyro', 'cryo')
    for _e in TRAVELER_ELEMENTS:
        GCSIM_CHARACTER_KEYS.add(f'aether{_e}')
        GCSIM_CHARACTER_KEYS.add(f'lumine{_e}')

    CHARACTER_NAME_OVERRIDES = {
        'kamisatoayaka': 'ayaka', 'kamisatoayato': 'ayato', 'raidenshogun': 'raiden',
        'sangonomiyakokomi': 'kokomi', 'kujousara': 'sara', 'kukishinobu': 'kuki',
        'shikanoinheizou': 'heizou', 'aratakiitto': 'itto', 'kaedeharakazuha': 'kazuha',
        'childe': 'tartaglia', 'scaramouche': 'wanderer', 'kusanali': 'nahida',
        'lesserlordkusanali': 'nahida',
    }

    # Full weapon/set/stat dictionaries
    GCSIM_WEAPON_KEYS = {
        'absolution', 'akuoumaru', 'alleyhunter', 'amenomakageuchi', 'amosbow', 'apprenticesnotes',
        'aquasimulacra', 'aquilafavonia', 'ashgravendrinkinghorn', 'astralvulturescrimsonplumage',
        'athousandblazingsuns', 'athousandfloatingdreams', 'azurelight', 'balladoftheboundlessblue',
        'balladofthefjords', 'beaconofthereedsea', 'beginnersprotector', 'blackcliffagate',
        'blackclifflongsword', 'blackcliffpole', 'blackcliffslasher', 'blackcliffwarbow',
        'blackmarrowlantern', 'blacktassel', 'bloodsoakedruins', 'bloodtaintedgreatsword',
        'calamityofeshu', 'calamityqueller', 'cashflowsupervision', 'chainbreaker', 'cinnabarspindle',
        'cloudforged', 'compoundbow', 'coolsteel', 'cranesechoingcall', 'crescentpike',
        'crimsonmoonssemblance', 'darkironsword', 'dawningfrost', 'deathmatch', 'debateclub',
        'dialoguesofthedesertsages', 'dodocotales', 'dragonsbane', 'dragonspinespear', 'dullblade',
        'earthshaker', 'elegyfortheend', 'emeraldorb', 'endoftheline', 'engulfinglightning',
        'etherlightspindlelute', 'everlastingmoonglow', 'eyeofperception', 'fadingtwilight',
        'fangofthemountainking', 'favoniuscodex', 'favoniusgreatsword', 'favoniuslance',
        'favoniussword', 'favoniuswarbow', 'ferrousshadow', 'festeringdesire', 'filletblade',
        'finaleofthedeep', 'fleuvecendreferryman', 'flowerwreathedfeathers', 'flowingpurity',
        'fluteofezpitzal', 'footprintoftherainbow', 'forestregalia', 'fracturedhalo', 'freedomsworn',
        'frostbearer', 'fruitfulhook', 'fruitoffulfillment', 'hakushinring', 'halberd', 'hamayumi',
        'harangeppakufutsu', 'harbingerofdawn', 'huntersbow', 'hunterspath', 'ibispiercer',
        'ironpoint', 'ironsting', 'jadefallssplendor', 'kagotsurubeisshin', 'kagurasverity',
        'katsuragikirinagamasa', 'keyofkhajnisut', 'kingssquire', 'kitaincrossspear',
        'lightoffoliarincision', 'lionsroar', 'lithicblade', 'lithicspear',
        'lostprayertothesacredwinds', 'lumidouceelegy', 'luxurioussealord', 'magicguide',
        'mailedflower', 'makhairaaquamarine', 'mappamare', 'masterkey', 'memoryofdust', 'messenger',
        'missivewindspear', 'mistsplitterreforged', 'mitternachtswaltz', 'moonpiercer',
        'moonweaversdawn', 'mountainbracingbolt', 'mouunsmoon', 'nightweaverslookingglass',
        'nocturnescurtaincall', 'oathsworneye', 'oldmercspal', 'otherworldlystory', 'peakpatrolsong',
        'pocketgrimoire', 'polarstar', 'portablepowersaw', 'predator', 'primordialjadecutter',
        'primordialjadewingedspear', 'prospectorsdrill', 'prospectorsshovel', 'prototypeamber',
        'prototypearchaic', 'prototypecrescent', 'prototyperancour', 'prototypestarglitter',
        'rainbowserpentbow', 'rainslasher', 'rangegauge', 'ravenbow', 'recurvebow',
        'redhornstonethresher', 'reliquaryoftruth', 'rightfulreward', 'ringofyaxche', 'royalbow',
        'royalgreatsword', 'royalgrimoire', 'royallongsword', 'royalspear', 'rust', 'sacrificersstaff',
        'sacrificialbow', 'sacrificialfragments', 'sacrificialgreatsword', 'sacrificialjade',
        'sacrificialsword', 'sapwoodblade', 'scionoftheblazingsun', 'seasonedhuntersbow',
        'sequenceofsolitude', 'serenityscall', 'serpentspine', 'sharpshootersoath',
        'silvershowerheartstrings', 'silversword', 'skyridergreatsword', 'skyridersword',
        'skywardatlas', 'skywardblade', 'skywardharp', 'skywardpride', 'skywardspine', 'slingshot',
        'snarehook', 'snowtombedstarsilver', 'solarpearl', 'songofbrokenpines', 'songofstillness',
        'splendoroftranquilwaters', 'staffofhoma', 'staffofthescarletsands', 'starcallerswatch',
        'sturdybone', 'summitshaper', 'sunnymorningsleepin', 'surfsup', 'swordofdescension',
        'swordofnarzissenkreuz', 'symphonistofscents', 'talkingstick', 'tamayurateinoohanashi',
        'thealleyflash', 'thebell', 'theblacksword', 'thecatch', 'thedockhandsassistant',
        'thefirstgreatmagic', 'theflute', 'thestringless', 'theunforged', 'theviridescenthunt',
        'thewidsith', 'thrillingtalesofdragonslayers', 'thunderingpulse', 'tidalshadow',
        'tomeoftheeternalflow', 'toukaboushigure', 'travelershandysword', 'tulaytullahsremembrance',
        'twinnephrite', 'ultimateoverlordsmegamagicsword', 'urakumisugiri', 'verdict', 'vividnotions',
        'vortexvanquisher', 'wanderingevenstar', 'wastergreatsword', 'wavebreakersfin',
        'waveridingwhirl', 'whiteblind', 'whiteirongreatsword', 'whitetassel', 'windblumeode',
        'wineandsong', 'wolffang', 'wolfsgravestone', 'xiphosmoonlight',
    }
    GCSIM_SET_KEYS = {
        'adventurer', 'archaicpetra', 'aubadeofmorningstarandmoon', 'berserker', 'blizzardstrayer',
        'bloodstainedchivalry', 'braveheart', 'crimsonwitchofflames', 'deepwoodmemories',
        'defenderswill', 'desertpavilionchronicle', 'echoesofanoffering', 'emblemofseveredfate',
        'finaleofthedeepgalleries', 'flowerofparadiselost', 'fragmentofharmonicwhimsy', 'gambler',
        'gildeddreams', 'gladiatorsfinale', 'goldentroupe', 'heartofdepth', 'huskofopulentdreams',
        'instructor', 'lavawalker', 'longnightsoath', 'luckydog', 'maidenbeloved',
        'marechausseehunter', 'martialartist', 'nightoftheskysunveiling',
        'nighttimewhispersintheechoingwoods', 'noblesseoblige', 'nymphsdream', 'obsidiancodex',
        'oceanhuedclam', 'paleflame', 'prayersfordestiny', 'prayersforillumination',
        'prayersforwisdom', 'prayerstospringtime', 'resolutionofsojourner', 'retracingbolide',
        'scholar', 'scrolloftheheroofcindercity', 'shimenawasreminiscence', 'silkenmoonsserenade',
        'songofdayspast', 'tenacityofthemillelith', 'theexile', 'thunderingfury', 'thundersoother',
        'tinymiracle', 'travelingdoctor', 'unfinishedreverie', 'vermillionhereafter',
        'viridescentvenerer', 'vourukashasglow', 'wandererstroupe',
    }
    FIGHT_PROP_TO_GCSIM = {
        'FIGHT_PROP_HP':                ('hp',       False),
        'FIGHT_PROP_HP_PERCENT':        ('hp%',      True),
        'FIGHT_PROP_ATTACK':            ('atk',      False),
        'FIGHT_PROP_ATTACK_PERCENT':    ('atk%',     True),
        'FIGHT_PROP_DEFENSE':           ('def',      False),
        'FIGHT_PROP_DEFENSE_PERCENT':   ('def%',     True),
        'FIGHT_PROP_CRITICAL':          ('cr',       True),
        'FIGHT_PROP_CRITICAL_HURT':     ('cd',       True),
        'FIGHT_PROP_CHARGE_EFFICIENCY': ('er',       True),
        'FIGHT_PROP_ELEMENT_MASTERY':   ('em',       False),
        'FIGHT_PROP_HEAL_ADD':          ('heal',     True),
        'FIGHT_PROP_FIRE_ADD_HURT':     ('pyro%',    True),
        'FIGHT_PROP_WATER_ADD_HURT':    ('hydro%',   True),
        'FIGHT_PROP_WIND_ADD_HURT':     ('anemo%',   True),
        'FIGHT_PROP_ICE_ADD_HURT':      ('cryo%',    True),
        'FIGHT_PROP_ELEC_ADD_HURT':     ('electro%', True),
        'FIGHT_PROP_GRASS_ADD_HURT':    ('dendro%',  True),
        'FIGHT_PROP_ROCK_ADD_HURT':     ('geo%',     True),
        'FIGHT_PROP_PHYSICAL_ADD_HURT': ('phys%',    True),
    }
    ELEMENT_DMG_PROP_TO_ELEMENT = {
        'FIGHT_PROP_FIRE_ADD_HURT':  'pyro',
        'FIGHT_PROP_WATER_ADD_HURT': 'hydro',
        'FIGHT_PROP_WIND_ADD_HURT':  'anemo',
        'FIGHT_PROP_ICE_ADD_HURT':   'cryo',
        'FIGHT_PROP_ELEC_ADD_HURT':  'electro',
        'FIGHT_PROP_GRASS_ADD_HURT': 'dendro',
        'FIGHT_PROP_ROCK_ADD_HURT':  'geo',
    }
    SUBSTAT_RE = re.compile(r'^([A-Z_]+)\+(-?[\d.]+)$')
    FILLER_ACTION = {
        'ganyu': 'aim',
        'neuvillette': 'charge',
    }

    # Traveler override handling
    traveler_override = traveler_override or {}

    # ---- Helper functions ----
    def _normalize(name):
        return re.sub(r"""[\s'".\-]""", "", str(name)).lower()

    def resolve_traveler(label, row, warnings):
        base = 'aether' if label.strip().lower() == 'aether' else 'lumine'
        if label in traveler_override:
            elem = traveler_override[label]
            warnings.append(f"{label}: using override element '{elem}'.")
            return f'{base}{elem}'
        for i in range(1, 6):
            main_type = row.get(f'Artifact {i} Main Stat Type')
            if pd.notna(main_type) and main_type in ELEMENT_DMG_PROP_TO_ELEMENT:
                elem = ELEMENT_DMG_PROP_TO_ELEMENT[main_type]
                warnings.append(f"{label}: auto-detected '{elem}' from goblet.")
                return f'{base}{elem}'
        for i in range(1, 6):
            for j in range(1, 5):
                sub = row.get(f'Artifact {i} Sub {j}')
                if pd.notna(sub):
                    for prop, elem in ELEMENT_DMG_PROP_TO_ELEMENT.items():
                        if str(sub).startswith(prop + '+'):
                            warnings.append(f"{label}: weak detection '{elem}' from substat.")
                            return f'{base}{elem}'
        warnings.append(f"{label}: defaulting to '{traveler_default}'.")
        return f'{base}{traveler_default}'

    def to_gcsim_name(csv_name, row, warnings):
        label = str(csv_name).strip()
        norm = _normalize(label)
        if norm in ('aether', 'lumine'):
            return resolve_traveler(label, row, warnings)
        if norm in CHARACTER_NAME_OVERRIDES:
            return CHARACTER_NAME_OVERRIDES[norm]
        if norm in GCSIM_CHARACTER_KEYS:
            return norm
        warnings.append(f"SKIPPED character '{label}': not in gcsim.")
        return None

    def to_gcsim_weapon(csv_weapon, char_label, warnings):
        norm = _normalize(csv_weapon)
        if norm in GCSIM_WEAPON_KEYS:
            return norm
        warnings.append(f"{char_label}: weapon '{csv_weapon}' not recognized.")
        return None

    def to_gcsim_set(csv_set, char_label, warnings):
        norm = _normalize(csv_set)
        if norm in GCSIM_SET_KEYS:
            return norm
        warnings.append(f"{char_label}: set '{csv_set}' not recognized.")
        return None

    def accumulate_artifact_stats(row, char_label, warnings):
        totals = {}
        unknown_types = set()

        def add(prop_type, raw_value):
            if prop_type not in FIGHT_PROP_TO_GCSIM:
                unknown_types.add(prop_type)
                return
            key, is_percent = FIGHT_PROP_TO_GCSIM[prop_type]
            v = raw_value / 100.0 if is_percent else raw_value
            totals[key] = totals.get(key, 0.0) + v

        for i in range(1, 6):
            main_type = row.get(f'Artifact {i} Main Stat Type')
            main_val = row.get(f'Artifact {i} Main Stat Value')
            if pd.notna(main_type) and pd.notna(main_val):
                add(str(main_type), float(main_val))
            for j in range(1, 5):
                sub = row.get(f'Artifact {i} Sub {j}')
                if pd.notna(sub):
                    m = SUBSTAT_RE.match(str(sub).strip())
                    if m:
                        add(m.group(1), float(m.group(2)))
                    else:
                        unknown_types.add(f"unparsable {sub!r}")
        if unknown_types:
            warnings.append(f"{char_label}: ignored unrecognized stat entries {sorted(unknown_types)}")
        return totals

    # ---- Build character configs ----
    def build_character_configs():
        df = pd.read_csv(csv_path, encoding='utf-8')
        df = df[df['Character Level'] >= min_character_level].copy()
        configs = {}
        skipped_unsupported = []
        warnings = []

        for _, row in df.iterrows():
            csv_name = row['Character Name']
            gcsim_name = to_gcsim_name(csv_name, row, warnings)
            if gcsim_name is None:
                skipped_unsupported.append(str(csv_name))
                continue

            char_label = f"{csv_name} -> {gcsim_name}"
            level = int(row['Character Level'])
            cons = int(row['Character Constellations']) if pd.notna(row.get('Character Constellations')) else 0
            na_raw = int(row['Talent NA Level']) if pd.notna(row.get('Talent NA Level')) else 1
            skill_raw = int(row['Talent Skill Level']) if pd.notna(row.get('Talent Skill Level')) else 1
            burst_raw = int(row['Talent Burst Level']) if pd.notna(row.get('Talent Burst Level')) else 1

            na, skill, burst = na_raw, skill_raw, burst_raw
            if cons >= 3 and skill > 10:
                skill = max(1, skill - 3)
                warnings.append(f"{char_label}: Skill boosted by C3, base {skill}.")
            if cons >= 5 and burst > 10:
                burst = max(1, burst - 3)
                warnings.append(f"{char_label}: Burst boosted by C5, base {burst}.")
            if na > 10:
                na = 10
                warnings.append(f"{char_label}: NA capped to 10.")
            na = max(1, min(10, na))
            skill = max(1, min(10, skill))
            burst = max(1, min(10, burst))

            lines = [
                f"{gcsim_name} char lvl={level}/90 cons={cons} talent={na},{skill},{burst} "
                f"+params=[start_energy=100];"
            ]
            weapon_name = row.get('Weapon Name')
            if pd.notna(weapon_name):
                weapon_key = to_gcsim_weapon(weapon_name, char_label, warnings)
                if weapon_key:
                    wlvl = int(row['Weapon Level']) if pd.notna(row.get('Weapon Level')) else 90
                    refine = int(row['Weapon Refinement']) if pd.notna(row.get('Weapon Refinement')) else 1
                    lines.append(f'{gcsim_name} add weapon="{weapon_key}" refine={refine} lvl={wlvl}/90;')
            set_counts = {}
            for i in range(1, 6):
                set_name = row.get(f'Artifact {i} Set')
                if pd.notna(set_name):
                    set_counts[set_name] = set_counts.get(set_name, 0) + 1
            for set_name, count in set_counts.items():
                if count < 2:
                    continue
                set_key = to_gcsim_set(set_name, char_label, warnings)
                if set_key:
                    lines.append(f'{gcsim_name} add set="{set_key}" count={count};')
            stat_totals = accumulate_artifact_stats(row, char_label, warnings)
            if stat_totals:
                stat_parts = [f'{k}={v:.4f}' for k, v in sorted(stat_totals.items())]
                lines.append(f'{gcsim_name} add stats {" ".join(stat_parts)};')
            if gcsim_name in configs:
                warnings.append(f"'{csv_name}' overwriting {gcsim_name}.")
            configs[gcsim_name] = '\n'.join(lines)

        print(f"Loaded {len(configs)} usable character(s): {sorted(configs.keys())}")
        if skipped_unsupported:
            print(f"\nSkipped {len(skipped_unsupported)} character(s) gcsim doesn't support yet:")
            for name in skipped_unsupported:
                print(f"  - {name}")
        if warnings:
            print(f"\n{len(warnings)} note(s)/warning(s):")
            for w in warnings:
                print(f"  - {w}")
        print()
        return configs

    char_configs = build_character_configs()
    all_chars = set(char_configs.keys())
    if lock_chars is None:
        lock_chars = []
    # Validate locked characters exist
    missing = [c for c in lock_chars if c not in all_chars]
    if missing:
        raise ValueError(f"Locked characters not in roster: {missing}")

    if len(all_chars) < 4:
        raise RuntimeError("Need at least 4 characters.")

    # ---- Rotation presets ----
    def preset_standard(team):
        active = team[0]
        body = ""
        for name in team:
            body += f'  if .{name}.burst.ready {{ {name} burst; }}\n'
            body += f'  if .{name}.skill.ready {{ {name} skill; }}\n'
        filler = FILLER_ACTION.get(active, 'attack')
        body += f'  {active} {filler};\n'
        return active, body

    def preset_support_first(team):
        main_dps = team[-1]
        others = team[:-1]
        active = team[0]
        body = ""
        for name in others:
            body += f'  if .{name}.burst.ready {{ {name} burst; }}\n'
        body += f'  if .{main_dps}.burst.ready {{ {main_dps} burst; }}\n'
        for name in team:
            body += f'  if .{name}.skill.ready {{ {name} skill; }}\n'
        filler = FILLER_ACTION.get(active, 'attack')
        body += f'  {active} {filler};\n'
        return active, body

    def preset_quickswap(team):
        active = team[0]
        body = ""
        for name in team:
            body += f'  if .{name}.skill.ready {{ {name} skill; }}\n'
        for name in team:
            body += f'  if .{name}.burst.ready {{ {name} burst; }}\n'
        filler = FILLER_ACTION.get(active, 'attack')
        body += f'  {active} {filler};\n'
        return active, body

    def preset_raiden_hyper(team):
        active = team[0]
        body = ""
        for name in team:
            body += f'  if .{name}.skill.ready {{ {name} skill; }}\n'
        for name in team:
            body += f'  if .{name}.burst.ready {{ {name} burst; }}\n'
        body += f'  if .{active}.name == "raiden" {{ {active} attack:15; }}\n'
        body += f'  else {{ {active} attack; }}\n'
        return active, body

    def preset_ganyu_aimed(team):
        active = team[0]
        body = ""
        for name in team:
            body += f'  if .{name}.burst.ready {{ {name} burst; }}\n'
            body += f'  if .{name}.skill.ready {{ {name} skill; }}\n'
        body += f'  if .{active}.name == "ganyu" {{ {active} aim; }}\n'
        body += f'  else {{ {active} attack; }}\n'
        return active, body

    def preset_wriothesley_charge(team):
        active = team[0]
        body = ""
        for name in team:
            body += f'  if .{name}.burst.ready {{ {name} burst; }}\n'
        for name in team:
            body += f'  if .{name}.skill.ready {{ {name} skill; }}\n'
        body += f'  if .{active}.name == "wriothesley" {{ {active} charge; }}\n'
        body += f'  else {{ {active} attack; }}\n'
        return active, body

    def preset_universal_filler_heavy(team):
        active = team[0]
        body = ""
        for name in team:
            body += f'  if .{name}.burst.ready {{ {name} burst; }}\n'
        for name in team:
            body += f'  if .{name}.skill.ready {{ {name} skill; }}\n'
        filler = FILLER_ACTION.get(active, 'attack')
        body += f'  {active} {filler},{filler},{filler};\n'
        return active, body

    def preset_burst_skill_weave(team):
        active = team[0]
        body = ""
        for name in team:
            body += f'  if .{name}.burst.ready {{ {name} burst; }}\n'
            body += f'  if .{name}.skill.ready {{ {name} skill; }}\n'
        filler = FILLER_ACTION.get(active, 'attack')
        body += f'  {active} {filler};\n'
        return active, body

    def preset_national(team):
        main_dps = team[-1]
        others = team[:-1]
        active = team[0]
        body = ""
        for name in others:
            body += f'  if .{name}.burst.ready {{ {name} burst; }}\n'
        body += f'  if .{main_dps}.burst.ready {{ {main_dps} burst; }}\n'
        for name in team:
            body += f'  if .{name}.skill.ready {{ {name} skill; }}\n'
        filler = FILLER_ACTION.get(active, 'attack')
        body += f'  {active} {filler};\n'
        return active, body

    def preset_hyperbloom_driver(team):
        active = team[0]
        body = ""
        for name in team:
            body += f'  if .{name}.burst.ready {{ {name} burst; }}\n'
            body += f'  if .{name}.skill.ready {{ {name} skill; }}\n'
        filler = FILLER_ACTION.get(active, 'attack')
        body += f'  {active} {filler}:6;\n'   # 6 normal attacks
        return active, body

    def preset_battery_first(team):
        active = team[0]
        body = ""
        for name in team:
            body += f'  if .{name}.skill.ready {{ {name} skill; }}\n'
        for name in team:
            body += f'  if .{name}.burst.ready {{ {name} burst; }}\n'
        filler = FILLER_ACTION.get(active, 'attack')
        body += f'  {active} {filler};\n'
        return active, body

    def preset_melt_ganyu_reverse(team):
        active = team[0]
        body = ""
        for name in team:
            body += f'  if .{name}.skill.ready {{ {name} skill; }}\n'
        for name in team:
            body += f'  if .{name}.burst.ready {{ {name} burst; }}\n'
        body += f'  if .{active}.name == "ganyu" {{ {active} aim; }}\n'
        body += f'  else {{ {active} attack; }}\n'
        return active, body

    def preset_tanky(team):
        active = team[0]
        body = ""
        for name in team:
            body += f'  if .{name}.burst.ready {{ {name} burst; }}\n'
            body += f'  if .{name}.skill.ready {{ {name} skill; }}\n'
        filler = FILLER_ACTION.get(active, 'attack')
        body += f'  {active} {filler},{filler};\n'   # 2 fillers
        return active, body

    def preset_kinich_skill(team):
        """Kinich on-field: skill, then use special attack chain."""
        active = team[0]
        body = ""
        # Use all bursts first (supports)
        for name in team:
            body += f'  if .{name}.burst.ready {{ {name} burst; }}\n'
        # Then skills
        for name in team:
            body += f'  if .{name}.skill.ready {{ {name} skill; }}\n'
        # If Kinich is active, do his enhanced string (attack:4 or charge based on his kit)
        body += f'  if .{active}.name == "kinich" {{ {active} attack:4; }}\n'
        body += f'  else {{ {active} attack; }}\n'
        return active, body



    ROTATION_PRESETS = [
    ("standard", preset_standard),
    ("support_first", preset_support_first),
    ("quickswap", preset_quickswap),
    ("raiden_hyper", preset_raiden_hyper),
    ("ganyu_aimed", preset_ganyu_aimed),
    ("wriothesley_charge", preset_wriothesley_charge),
    ("universal_heavy_filler", preset_universal_filler_heavy),
    ("burst_skill_weave", preset_burst_skill_weave),
    ("national", preset_national),
    ("hyperbloom_driver", preset_hyperbloom_driver),
    ("melt_ganyu_reverse", preset_melt_ganyu_reverse),
    ("battery_first", preset_battery_first),
    ("tanky", preset_tanky),
    ("kinich_skill", preset_kinich_skill),
    ]

    # ---- Build full config ----
    def build_full_config(team):
        preset_id, start_idx, *chars = team
        preset_func = ROTATION_PRESETS[preset_id][1]
        _, rotation_body = preset_func(chars)
        active = chars[start_idx]
        config = f"""
options iteration={sim_iterations} duration={sim_duration} swap_delay=4;
target lvl=100 resist=0.1 particle_threshold=250000 particle_drop_count=1;

"""
        for name in chars:
            config += char_configs[name] + '\n'
        config += f'active {active};\n\n'
        config += 'while 1 {\n'
        config += rotation_body
        config += '}\n'
        return config

    # ---- Run gcsim and return objectives dict ----
    def run_gcsim(config_str):
        with tempfile.NamedTemporaryFile(mode='w', suffix='.txt', delete=False) as f:
            f.write(config_str)
            config_path = f.name
        output_path = config_path + '.json'
        try:
            result = subprocess.run(
                [gcsim_bin, '-c', config_path, '-out', output_path],
                capture_output=True, text=True, timeout=120
            )
            if result.returncode != 0:
                return {'dps': 0.0, 'max_hit': 0.0, 'sd': 0.0}
            with open(output_path, 'r') as jf:
                data = json.load(jf)
            stats = data['statistics']
            dps = stats['dps']['mean']
            sd = stats['dps']['sd']

            # Extract max single hit from damage buckets
            max_hit = 0.0
            buckets_info = stats.get('damage_buckets')
            if buckets_info:
                bucket_list = buckets_info.get('buckets', [])
                for bucket in bucket_list:
                    if isinstance(bucket, dict):
                        max_hit = max(max_hit, bucket.get('max', 0.0))

            # Fallback to total_damage if buckets missing
            if max_hit == 0.0:
                max_hit = stats.get('total_damage', 0.0)

            return {'dps': dps, 'max_hit': max_hit, 'sd': sd}
        except Exception as e:
            import sys
            print(f"Exception in run_gcsim: {e}", file=sys.stderr)
            return {'dps': 0.0, 'max_hit': 0.0, 'sd': 0.0}
        finally:
            for f in [config_path, output_path]:
                if os.path.exists(f):
                    os.unlink(f)

    # ---- EA functions ----
    def random_team():
        preset = random.randrange(len(ROTATION_PRESETS))
        start_idx = random.randrange(4)
        # Always include locked characters first (order shuffled)
        locked = list(lock_chars)
        random.shuffle(locked)
        needed = 4 - len(locked)
        others = random.sample(list(all_chars - set(locked)), needed)
        chars = locked + others
        random.shuffle(chars)   # mix order so EA can evolve best sequence
        return (preset, start_idx) + tuple(chars)

    def fitness(team):
        config = build_full_config(team)
        return run_gcsim(config)

    def tournament_selection(population, scores):
        selected = random.sample(list(zip(population, scores)), tournament_size)
        selected.sort(key=lambda x: x[1]['dps'], reverse=True)
        return selected[0][0]

    def crossover(p1, p2):
        # inherit preset & start_idx
        child = [
            p1[0] if random.random() < 0.5 else p2[0],
            p1[1] if random.random() < 0.5 else p2[1],
        ]
        # crossover the 4 character slots
        raw_chars = []
        for i in range(2, len(p1)):
            raw_chars.append(p1[i] if random.random() < 0.5 else p2[i])

        # ---- enforce locked characters exactly once ----
        # 1. remove any extra locked characters (keep first occurrence)
        first_occurrence = {}
        for i, c in enumerate(raw_chars):
            if c in lock_chars and c not in first_occurrence:
                first_occurrence[c] = i

        # 2. fill missing locked characters
        present_locked = set(first_occurrence.keys())
        missing_locked = [lc for lc in lock_chars if lc not in present_locked]
        # indices of slots that are NOT a locked character
        free_slots = [i for i, c in enumerate(raw_chars) if c not in lock_chars]
        random.shuffle(free_slots)

        for lc in missing_locked:
            if free_slots:
                idx = free_slots.pop()
                raw_chars[idx] = lc
            else:
                # fallback: replace a random slot (shouldn’t happen if len(lock_chars) ≤ 4)
                idx = random.randrange(4)
                while raw_chars[idx] in lock_chars:
                    idx = random.randrange(4)
                raw_chars[idx] = lc

        # 3. fill remaining slots with unique non‑locked characters
        current_chars = set(raw_chars)
        needed = 4 - len(current_chars)
        if needed > 0:
            available = list(all_chars - current_chars)
            random.shuffle(available)
            for i in range(4):
                if raw_chars[i] in lock_chars and raw_chars.count(raw_chars[i]) > 1:
                    # replace duplicate locked (edge case)
                    raw_chars[i] = available.pop()
                elif raw_chars[i] not in lock_chars and current_chars:
                    # already fine
                    pass
            # a simpler final pass: just ensure no duplicates
            seen = set()
            for i in range(4):
                if raw_chars[i] in seen:
                    if available:
                        raw_chars[i] = available.pop()
                    else:
                        # fallback random
                        pool = list(all_chars - set(raw_chars))
                        if pool:
                            raw_chars[i] = random.choice(pool)
                seen.add(raw_chars[i])

        child.extend(raw_chars)
        return tuple(child)

    def mutate(team):
        if random.random() < mutation_rate:
            team_list = list(team)
            r = random.random()
            if r < 0.1:
                team_list[0] = random.randrange(len(ROTATION_PRESETS))
            elif r < 0.2:
                team_list[1] = random.randrange(4)
            else:
                # Only mutate a non‑locked character
                mutable_indices = [i for i in range(2, len(team_list))
                                  if team_list[i] not in lock_chars]
                if mutable_indices:
                    idx = random.choice(mutable_indices)
                    available = [c for c in all_chars
                                if c not in team_list[2:]]
                    if available:
                        team_list[idx] = random.choice(available)
            return tuple(team_list)
        return team

    def dominates(a, b):
        better = False
        if a['dps'] > b['dps']: better = True
        elif a['dps'] < b['dps']: return False
        if a['max_hit'] > b['max_hit']: better = True
        elif a['max_hit'] < b['max_hit']: return False
        if a['sd'] < b['sd']: better = True
        elif a['sd'] > b['sd']: return False
        return better

    # ---- CREATE OUTPUT FOLDER (per run) ----
    root_output = "optimizer_results"
    os.makedirs(root_output, exist_ok=True)
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    run_dir = os.path.join(root_output, f"{save_prefix}_{timestamp}")
    os.makedirs(run_dir, exist_ok=True)
    print(f"Output folder: {run_dir}")

    def save_file(filename, content):
        filepath = os.path.join(run_dir, filename)
        with open(filepath, 'w') as f:
            f.write(content)
        return filepath

    # ---- Main EA loop ----
    population = [random_team() for _ in range(population_size)]
    best_overall = (None, {'dps': 0.0, 'max_hit': 0.0, 'sd': 0.0})
    pareto_archive = []   # only used if pareto=True

    mode_str = "Pareto multi‑objective" if pareto else "pure DPS"
    print(f"Starting EA: pop={population_size}, gen={generations}, duration={sim_duration}s, iterations={sim_iterations}, mode={mode_str}")

    # Quick debug
    debug_team = (0, 0) + tuple(list(all_chars)[:4])
    test_res = fitness(debug_team)
    print(f"Debug team DPS: {test_res['dps']:.0f}, max_hit: {test_res['max_hit']:.0f}")

    try:
        for gen in range(generations):
            print(f"\nGeneration {gen+1}/{generations}")
            scores = [fitness(ind) for ind in population]
            unique_teams = set(population)
            print(f"Unique individuals: {len(unique_teams)}/{population_size}")

            # Update Pareto archive only if enabled
            if pareto:
                for team, obj in zip(population, scores):
                    dominated = False
                    for _, aobj in pareto_archive:
                        if dominates(aobj, obj):
                            dominated = True
                            break
                    if not dominated:
                        pareto_archive = [(t, o) for t, o in pareto_archive if not dominates(obj, o)]
                        pareto_archive.append((team, obj))

            fitness_vals = [s['dps'] for s in scores]
            top_indices = sorted(range(len(fitness_vals)), key=lambda i: fitness_vals[i], reverse=True)[:5]
            print("Top 5 this gen:")
            for idx in top_indices:
                preset_id, start_idx, *chars = population[idx]
                preset_name = ROTATION_PRESETS[preset_id][0]
                obj = scores[idx]
                print(f"  [{preset_name}] start:{chars[start_idx]} team:{chars} DPS:{obj['dps']:.0f} MaxHit:{obj['max_hit']:.0f}")

            best_idx = fitness_vals.index(max(fitness_vals))
            best_team = population[best_idx]
            best_obj = scores[best_idx]
            if best_obj['dps'] > best_overall[1]['dps']:
                best_overall = (best_team, best_obj)

            print(f"Gen best: {best_team} DPS:{best_obj['dps']:.0f} MaxHit:{best_obj['max_hit']:.0f}")
            print(f"Overall best: {best_overall[0]} DPS:{best_overall[1]['dps']:.0f} MaxHit:{best_overall[1]['max_hit']:.0f}")

            elite_count = max(1, int(population_size * 0.2))
            combined = sorted(zip(population, fitness_vals), key=lambda x: x[1], reverse=True)
            elites = [ind for ind, _ in combined[:elite_count]]
            new_pop = elites.copy()
            while len(new_pop) < population_size:
                p1 = tournament_selection(population, scores)
                p2 = tournament_selection(population, scores)
                if random.random() < crossover_rate:
                    child = crossover(p1, p2)
                else:
                    child = p1
                child = mutate(child)
                new_pop.append(child)
            population = new_pop

    except KeyboardInterrupt:
        print("\nInterrupted! Saving best so far.")
        if best_overall[0] is not None:
            config = build_full_config(best_overall[0])
            save_file("best_team_interrupted.txt", config)
        if pareto and pareto_archive:
            pareto_sorted = sorted(pareto_archive, key=lambda x: x[1]['dps'], reverse=True)[:10]
            for i, (t, obj) in enumerate(pareto_sorted):
                config = build_full_config(t)
                save_file(f"pareto_interrupted_{i+1}.txt", config)
        raise

    # Final output
    print("\n===== FINAL BEST TEAM (by DPS) =====")
    best_team_tuple = best_overall[0]
    best_obj = best_overall[1]
    best_config = build_full_config(best_team_tuple)
    print(f"DPS: {best_obj['dps']:.0f}  MaxHit: {best_obj['max_hit']:.0f}")
    print(best_config)
    save_file("best_team.txt", best_config)

    if pareto and pareto_archive:
        print("\n===== PARETO FRONT (top 10) =====")
        pareto_archive.sort(key=lambda x: x[1]['dps'], reverse=True)
        top_10_pareto = pareto_archive[:10]
        for i, (team, obj) in enumerate(top_10_pareto):
            preset_id, start_idx, *chars = team
            preset_name = ROTATION_PRESETS[preset_id][0]
            print(f"#{i+1} [{preset_name}] start:{chars[start_idx]} {chars}")
            print(f"   DPS:{obj['dps']:.0f}  MaxHit:{obj['max_hit']:.0f}  SD:{obj['sd']:.0f}")
            config = build_full_config(team)
            save_file(f"pareto_{i+1}.txt", config)
        # Save a JSON summary of the Pareto front
        summary = []
        for team, obj in top_10_pareto:
            preset_id, start_idx, *chars = team
            summary.append({
                'preset': ROTATION_PRESETS[preset_id][0],
                'start_char': chars[start_idx],
                'team': chars,
                'dps': obj['dps'],
                'max_hit': obj['max_hit'],
                'sd': obj['sd']
            })
        with open(os.path.join(run_dir, 'pareto_summary.json'), 'w') as f:
            json.dump(summary, f, indent=2)
    else:
        print("\n(Pareto archive disabled – only the single best DPS team is shown)")

# ---- Call the function with your desired settings ----
if __name__ == "__main__":
    # Example 1: multi‑objective (Pareto) – you get best DPS + nuke + consistent teams
    run_optimizer(
        #lock_chars=["ganyu"],
        csv_path="genshin_data_export.csv",
        gcsim_bin="./gcsim",
        sim_duration=90,
        sim_iterations=10,
        population_size=2000,
        generations=50,
        mutation_rate=0.4,
        save_prefix="general",
        pareto=True          # <-- this enables the Pareto front
    )

    # Example 2: pure DPS – only the team with the highest average DPS matters
    # run_optimizer(
    #     lock_chars=["neuvillette", "furina"],
    #     csv_path="genshin_data_export.csv",
    #     gcsim_bin="./gcsim",
    #     sim_duration=90,
    #     generations=50,
    #     population_size=150,
    #     save_prefix="pure_dps_test",
    #     pareto=False
    # )
# Out:
# Loaded 35 usable character(s): ['aetherdendro', 'ayato', 'barbara', 'beidou', 'bennett', 'charlotte', 'chevreuse', 'chongyun', 'citlali', 'collei', 'diona', 'fischl', 'furina', 'ganyu', 'heizou', 'jean', 'kinich', 'kuki', 'mavuika', 'mona', 'navia', 'neuvillette', 'ningguang', 'raiden', 'rosaria', 'sara', 'skirk', 'sucrose', 'venti', 'wriothesley', 'xiangling', 'xingqiu', 'yanfei', 'yelan', 'yunjin']
#
# Skipped 3 character(s) gcsim doesn't support yet:
#   - Nicole
#   - Durin
#   - Iansan
#
# 7 note(s)/warning(s):
#   - SKIPPED character 'Nicole': not in gcsim.
#   - SKIPPED character 'Durin': not in gcsim.
#   - Xingqiu -> xingqiu: Skill boosted by C3, base 8.
#   - Bennett -> bennett: Burst boosted by C5, base 8.
#   - Diona -> diona: Skill boosted by C3, base 8.
#   - SKIPPED character 'Iansan': not in gcsim.
#   - Aether: auto-detected 'dendro' from goblet.
#
# Output folder: optimizer_results/general_20260617_213611
# Starting EA: pop=2000, gen=50, duration=90s, iterations=10, mode=Pareto multi‑objective
# Debug team DPS: 8778, max_hit: 40333
#
# Generation 1/50
# Unique individuals: 2000/2000
# Top 5 this gen:
#   [support_first] start:furina team:['ganyu', 'mavuika', 'bennett', 'furina'] DPS:31677 MaxHit:191904
#   [battery_first] start:sucrose team:['sucrose', 'jean', 'furina', 'fischl'] DPS:31453 MaxHit:80086
#   [battery_first] start:furina team:['mavuika', 'rosaria', 'raiden', 'furina'] DPS:28551 MaxHit:150669
#   [standard] start:fischl team:['furina', 'collei', 'fischl', 'mavuika'] DPS:26691 MaxHit:112618
#   [battery_first] start:mavuika team:['mavuika', 'xingqiu', 'fischl', 'yanfei'] DPS:26677 MaxHit:147980
# Gen best: (1, 3, 'ganyu', 'mavuika', 'bennett', 'furina') DPS:31677 MaxHit:191904
# Overall best: (1, 3, 'ganyu', 'mavuika', 'bennett', 'furina') DPS:31677 MaxHit:191904
#
# Generation 2/50
# Unique individuals: 1868/2000
# Top 5 this gen:
#   [burst_skill_weave] start:mavuika team:['ganyu', 'mavuika', 'citlali', 'bennett'] DPS:36675 MaxHit:413130
#   [burst_skill_weave] start:neuvillette team:['neuvillette', 'xiangling', 'fischl', 'furina'] DPS:34283 MaxHit:92205
#   [support_first] start:mavuika team:['neuvillette', 'mavuika', 'kuki', 'furina'] DPS:33394 MaxHit:120724
#   [support_first] start:furina team:['ganyu', 'mavuika', 'bennett', 'furina'] DPS:32651 MaxHit:203771
#   [battery_first] start:sucrose team:['sucrose', 'jean', 'furina', 'fischl'] DPS:32649 MaxHit:71691
# Gen best: (7, 1, 'ganyu', 'mavuika', 'citlali', 'bennett') DPS:36675 MaxHit:413130
# Overall best: (7, 1, 'ganyu', 'mavuika', 'citlali', 'bennett') DPS:36675 MaxHit:413130
#
# Generation 3/50
# Unique individuals: 1834/2000
# Top 5 this gen:
#   [burst_skill_weave] start:neuvillette team:['neuvillette', 'sucrose', 'fischl', 'furina'] DPS:40408 MaxHit:91580
#   [burst_skill_weave] start:mavuika team:['ganyu', 'mavuika', 'citlali', 'bennett'] DPS:36498 MaxHit:410556
#   [burst_skill_weave] start:neuvillette team:['neuvillette', 'raiden', 'citlali', 'furina'] DPS:36423 MaxHit:90867
#   [burst_skill_weave] start:neuvillette team:['neuvillette', 'xiangling', 'fischl', 'furina'] DPS:35506 MaxHit:80483
#   [burst_skill_weave] start:bennett team:['ganyu', 'mavuika', 'furina', 'bennett'] DPS:35159 MaxHit:185876
# Gen best: (7, 0, 'neuvillette', 'sucrose', 'fischl', 'furina') DPS:40408 MaxHit:91580
# Overall best: (7, 0, 'neuvillette', 'sucrose', 'fischl', 'furina') DPS:40408 MaxHit:91580
#
# Generation 4/50
# Unique individuals: 1798/2000
# Top 5 this gen:
#   [quickswap] start:furina team:['neuvillette', 'mavuika', 'fischl', 'furina'] DPS:39853 MaxHit:123080
#   [burst_skill_weave] start:neuvillette team:['neuvillette', 'sucrose', 'fischl', 'furina'] DPS:39818 MaxHit:95257
#   [burst_skill_weave] start:fischl team:['neuvillette', 'sucrose', 'fischl', 'furina'] DPS:38899 MaxHit:96744
#   [burst_skill_weave] start:mavuika team:['ganyu', 'mavuika', 'citlali', 'bennett'] DPS:38308 MaxHit:402155
#   [standard] start:furina team:['mavuika', 'sucrose', 'furina', 'fischl'] DPS:38112 MaxHit:237710
# Gen best: (2, 3, 'neuvillette', 'mavuika', 'fischl', 'furina') DPS:39853 MaxHit:123080
# Overall best: (7, 0, 'neuvillette', 'sucrose', 'fischl', 'furina') DPS:40408 MaxHit:91580
#
# Generation 5/50
# Unique individuals: 1815/2000
# Top 5 this gen:
#   [battery_first] start:furina team:['neuvillette', 'furina', 'mavuika', 'fischl'] DPS:42118 MaxHit:131438
#   [battery_first] start:neuvillette team:['neuvillette', 'furina', 'mavuika', 'fischl'] DPS:42100 MaxHit:128219
#   [quickswap] start:neuvillette team:['neuvillette', 'jean', 'furina', 'fischl'] DPS:41277 MaxHit:102069
#   [quickswap] start:furina team:['neuvillette', 'mavuika', 'fischl', 'furina'] DPS:39842 MaxHit:123790
#   [burst_skill_weave] start:fischl team:['neuvillette', 'sucrose', 'fischl', 'furina'] DPS:39256 MaxHit:88594
# Gen best: (11, 1, 'neuvillette', 'furina', 'mavuika', 'fischl') DPS:42118 MaxHit:131438
# Overall best: (11, 1, 'neuvillette', 'furina', 'mavuika', 'fischl') DPS:42118 MaxHit:131438
#
# Generation 6/50
# Unique individuals: 1781/2000
# Top 5 this gen:
#   [quickswap] start:neuvillette team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:43722 MaxHit:165093
#   [battery_first] start:neuvillette team:['neuvillette', 'furina', 'mavuika', 'fischl'] DPS:43194 MaxHit:152455
#   [battery_first] start:neuvillette team:['neuvillette', 'furina', 'mavuika', 'fischl'] DPS:42890 MaxHit:150743
#   [battery_first] start:furina team:['neuvillette', 'furina', 'mavuika', 'fischl'] DPS:42054 MaxHit:158259
#   [quickswap] start:furina team:['neuvillette', 'furina', 'fischl', 'citlali'] DPS:42015 MaxHit:80553
# Gen best: (2, 0, 'neuvillette', 'mavuika', 'furina', 'citlali') DPS:43722 MaxHit:165093
# Overall best: (2, 0, 'neuvillette', 'mavuika', 'furina', 'citlali') DPS:43722 MaxHit:165093
#
# Generation 7/50
# Unique individuals: 1756/2000
# Top 5 this gen:
#   [battery_first] start:neuvillette team:['neuvillette', 'furina', 'mavuika', 'fischl'] DPS:43178 MaxHit:147792
#   [quickswap] start:neuvillette team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:43158 MaxHit:193726
#   [quickswap] start:furina team:['neuvillette', 'furina', 'fischl', 'citlali'] DPS:43048 MaxHit:90959
#   [quickswap] start:mavuika team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:42725 MaxHit:199362
#   [battery_first] start:neuvillette team:['neuvillette', 'furina', 'mavuika', 'fischl'] DPS:42717 MaxHit:151599
# Gen best: (11, 0, 'neuvillette', 'furina', 'mavuika', 'fischl') DPS:43178 MaxHit:147792
# Overall best: (2, 0, 'neuvillette', 'mavuika', 'furina', 'citlali') DPS:43722 MaxHit:165093
#
# Generation 8/50
# Unique individuals: 1705/2000
# Top 5 this gen:
#   [quickswap] start:mavuika team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:44329 MaxHit:192942
#   [quickswap] start:mavuika team:['neuvillette', 'citlali', 'furina', 'mavuika'] DPS:44325 MaxHit:191247
#   [quickswap] start:mavuika team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:43897 MaxHit:213466
#   [quickswap] start:neuvillette team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:43657 MaxHit:169292
#   [quickswap] start:mavuika team:['neuvillette', 'citlali', 'furina', 'mavuika'] DPS:42979 MaxHit:191485
# Gen best: (2, 1, 'neuvillette', 'mavuika', 'furina', 'citlali') DPS:44329 MaxHit:192942
# Overall best: (2, 1, 'neuvillette', 'mavuika', 'furina', 'citlali') DPS:44329 MaxHit:192942
#
# Generation 9/50
# Unique individuals: 1597/2000
# Top 5 this gen:
#   [battery_first] start:citlali team:['neuvillette', 'mavuika', 'citlali', 'furina'] DPS:44186 MaxHit:193150
#   [quickswap] start:neuvillette team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:43936 MaxHit:167042
#   [quickswap] start:mavuika team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:43822 MaxHit:185889
#   [battery_first] start:neuvillette team:['neuvillette', 'mavuika', 'citlali', 'furina'] DPS:43774 MaxHit:157953
#   [quickswap] start:mavuika team:['neuvillette', 'citlali', 'furina', 'mavuika'] DPS:43685 MaxHit:197785
# Gen best: (11, 2, 'neuvillette', 'mavuika', 'citlali', 'furina') DPS:44186 MaxHit:193150
# Overall best: (2, 1, 'neuvillette', 'mavuika', 'furina', 'citlali') DPS:44329 MaxHit:192942
#
# Generation 10/50
# Unique individuals: 1456/2000
# Top 5 this gen:
#   [quickswap] start:mavuika team:['neuvillette', 'citlali', 'furina', 'mavuika'] DPS:44512 MaxHit:191717
#   [quickswap] start:citlali team:['neuvillette', 'mavuika', 'citlali', 'furina'] DPS:44214 MaxHit:193150
#   [quickswap] start:furina team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:44194 MaxHit:192587
#   [quickswap] start:furina team:['neuvillette', 'mavuika', 'citlali', 'furina'] DPS:43983 MaxHit:193150
#   [quickswap] start:furina team:['neuvillette', 'mavuika', 'citlali', 'furina'] DPS:43974 MaxHit:193150
# Gen best: (2, 3, 'neuvillette', 'citlali', 'furina', 'mavuika') DPS:44512 MaxHit:191717
# Overall best: (2, 3, 'neuvillette', 'citlali', 'furina', 'mavuika') DPS:44512 MaxHit:191717
#
# Generation 11/50
# Unique individuals: 1328/2000
# Top 5 this gen:
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45137 MaxHit:231562
#   [quickswap] start:furina team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:44944 MaxHit:213466
#   [quickswap] start:mavuika team:['neuvillette', 'citlali', 'furina', 'mavuika'] DPS:44889 MaxHit:197785
#   [battery_first] start:citlali team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:44644 MaxHit:190489
#   [quickswap] start:citlali team:['neuvillette', 'mavuika', 'citlali', 'furina'] DPS:44532 MaxHit:193150
# Gen best: (11, 3, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:45137 MaxHit:231562
# Overall best: (11, 3, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:45137 MaxHit:231562
#
# Generation 12/50
# Unique individuals: 1192/2000
# Top 5 this gen:
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45236 MaxHit:221581
#   [quickswap] start:mavuika team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:44745 MaxHit:195991
#   [quickswap] start:mavuika team:['neuvillette', 'mavuika', 'citlali', 'furina'] DPS:44703 MaxHit:175540
#   [quickswap] start:mavuika team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:44622 MaxHit:211949
#   [battery_first] start:furina team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:44596 MaxHit:195991
# Gen best: (11, 3, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:45236 MaxHit:221581
# Overall best: (11, 3, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:45236 MaxHit:221581
#
# Generation 13/50
# Unique individuals: 1054/2000
# Top 5 this gen:
#   [quickswap] start:citlali team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45230 MaxHit:221581
#   [quickswap] start:mavuika team:['neuvillette', 'citlali', 'mavuika', 'furina'] DPS:45169 MaxHit:218638
#   [battery_first] start:citlali team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:45112 MaxHit:185889
#   [quickswap] start:mavuika team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:44906 MaxHit:195991
#   [battery_first] start:furina team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:44770 MaxHit:184689
# Gen best: (2, 2, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:45230 MaxHit:221581
# Overall best: (11, 3, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:45236 MaxHit:221581
#
# Generation 14/50
# Unique individuals: 979/2000
# Top 5 this gen:
#   [quickswap] start:furina team:['neuvillette', 'citlali', 'mavuika', 'furina'] DPS:45650 MaxHit:256231
#   [quickswap] start:citlali team:['neuvillette', 'mavuika', 'citlali', 'furina'] DPS:45114 MaxHit:193150
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45084 MaxHit:208891
#   [battery_first] start:neuvillette team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45050 MaxHit:209910
#   [quickswap] start:furina team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:45024 MaxHit:185889
# Gen best: (2, 3, 'neuvillette', 'citlali', 'mavuika', 'furina') DPS:45650 MaxHit:256231
# Overall best: (2, 3, 'neuvillette', 'citlali', 'mavuika', 'furina') DPS:45650 MaxHit:256231
#
# Generation 15/50
# Unique individuals: 890/2000
# Top 5 this gen:
#   [quickswap] start:furina team:['neuvillette', 'citlali', 'mavuika', 'furina'] DPS:45919 MaxHit:214920
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45529 MaxHit:236525
#   [quickswap] start:furina team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:45384 MaxHit:185889
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45297 MaxHit:230689
#   [quickswap] start:mavuika team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:45236 MaxHit:179797
# Gen best: (2, 3, 'neuvillette', 'citlali', 'mavuika', 'furina') DPS:45919 MaxHit:214920
# Overall best: (2, 3, 'neuvillette', 'citlali', 'mavuika', 'furina') DPS:45919 MaxHit:214920
#
# Generation 16/50
# Unique individuals: 847/2000
# Top 5 this gen:
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:46079 MaxHit:238841
#   [quickswap] start:furina team:['neuvillette', 'citlali', 'mavuika', 'furina'] DPS:45941 MaxHit:224237
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45632 MaxHit:232271
#   [battery_first] start:citlali team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45464 MaxHit:231562
#   [quickswap] start:furina team:['neuvillette', 'citlali', 'mavuika', 'furina'] DPS:45386 MaxHit:229198
# Gen best: (11, 3, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46079 MaxHit:238841
# Overall best: (11, 3, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46079 MaxHit:238841
#
# Generation 17/50
# Unique individuals: 843/2000
# Top 5 this gen:
#   [quickswap] start:citlali team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:46371 MaxHit:232304
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45798 MaxHit:198445
#   [quickswap] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45785 MaxHit:232271
#   [quickswap] start:furina team:['neuvillette', 'mavuika', 'furina', 'citlali'] DPS:45772 MaxHit:195991
#   [battery_first] start:furina team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45506 MaxHit:221581
# Gen best: (2, 2, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46371 MaxHit:232304
# Overall best: (2, 2, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46371 MaxHit:232304
#
# Generation 18/50
# Unique individuals: 872/2000
# Top 5 this gen:
#   [battery_first] start:neuvillette team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45926 MaxHit:220488
#   [quickswap] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45681 MaxHit:236525
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45605 MaxHit:221581
#   [battery_first] start:neuvillette team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45557 MaxHit:220488
#   [quickswap] start:furina team:['neuvillette', 'citlali', 'mavuika', 'furina'] DPS:45557 MaxHit:249228
# Gen best: (11, 0, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:45926 MaxHit:220488
# Overall best: (2, 2, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46371 MaxHit:232304
#
# Generation 19/50
# Unique individuals: 903/2000
# Top 5 this gen:
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:46172 MaxHit:232980
#   [quickswap] start:citlali team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:46111 MaxHit:232271
#   [battery_first] start:furina team:['neuvillette', 'citlali', 'mavuika', 'furina'] DPS:46017 MaxHit:215432
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45927 MaxHit:232271
#   [battery_first] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45881 MaxHit:230095
# Gen best: (11, 3, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46172 MaxHit:232980
# Overall best: (2, 2, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46371 MaxHit:232304
#
# Generation 20/50
# Unique individuals: 867/2000
# Top 5 this gen:
#   [quickswap] start:furina team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:46589 MaxHit:232980
#   [battery_first] start:citlali team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:46498 MaxHit:198877
#   [quickswap] start:citlali team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45999 MaxHit:232271
#   [quickswap] start:furina team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45950 MaxHit:238841
#   [battery_first] start:neuvillette team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45827 MaxHit:220493
# Gen best: (2, 1, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46589 MaxHit:232980
# Overall best: (2, 1, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46589 MaxHit:232980
#
# Generation 21/50
# Unique individuals: 754/2000
# Top 5 this gen:
#   [battery_first] start:citlali team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:46072 MaxHit:231562
#   [battery_first] start:citlali team:['neuvillette', 'citlali', 'mavuika', 'furina'] DPS:45948 MaxHit:256231
#   [battery_first] start:furina team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45920 MaxHit:238628
#   [battery_first] start:citlali team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45906 MaxHit:236517
#   [quickswap] start:mavuika team:['neuvillette', 'furina', 'citlali', 'mavuika'] DPS:45881 MaxHit:198445
# Gen best: (11, 2, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46072 MaxHit:231562
# Overall best: (2, 1, 'neuvillette', 'furina', 'citlali', 'mavuika') DPS:46589 MaxHit:232980
#
# Generation 22/50
#
# Interrupted! Saving best so far.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_713/2962276015.py in <cell line: 0>()
#     825 if __name__ == "__main__":
#     826     # Example 1: multi‑objective (Pareto) – you get best DPS + nuke + consistent teams
# --> 827     run_optimizer(
#     828         #lock_chars=["ganyu"],
#     829         csv_path="genshin_data_export.csv",
#
# /tmp/ipykernel_713/2962276015.py in run_optimizer(lock_chars, csv_path, gcsim_bin, sim_duration, sim_iterations, population_size, generations, mutation_rate, crossover_rate, tournament_size, min_character_level, traveler_override, traveler_default, save_prefix, pareto)
#     724         for gen in range(generations):
#     725             print(f"\nGeneration {gen+1}/{generations}")
# --> 726             scores = [fitness(ind) for ind in population]
#     727             unique_teams = set(population)
#     728             print(f"Unique individuals: {len(unique_teams)}/{population_size}")
#
# /tmp/ipykernel_713/2962276015.py in fitness(team)
#     591     def fitness(team):
#     592         config = build_full_config(team)
# --> 593         return run_gcsim(config)
#     594
#     595     def tournament_selection(population, scores):
#
# /tmp/ipykernel_713/2962276015.py in run_gcsim(config_str)
#     541         output_path = config_path + '.json'
#     542         try:
# --> 543             result = subprocess.run(
#     544                 [gcsim_bin, '-c', config_path, '-out', output_path],
#     545                 capture_output=True, text=True, timeout=120
#
# /usr/lib/python3.12/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548     with Popen(*popenargs, **kwargs) as process:
#     549         try:
# --> 550             stdout, stderr = process.communicate(input, timeout=timeout)
#     551         except TimeoutExpired as exc:
#     552             process.kill()
#
# /usr/lib/python3.12/subprocess.py in communicate(self, input, timeout)
#    1207
#    1208             try:
# -> 1209                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1210             except KeyboardInterrupt:
#    1211                 # https://bugs.python.org/issue25942
#
# /usr/lib/python3.12/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    2113                             'failed to raise TimeoutExpired.')
#    2114
# -> 2115                     ready = selector.select(timeout)
#    2116                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2117
#
# /usr/lib/python3.12/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %% [markdown]
# # Rotation Sequence Learner

# %%
import pandas as pd
import subprocess
import json
import random
import re
import tempfile
import os
from datetime import datetime
import math
from collections import Counter

# -----------------------------------------------------------------
#  Parameterised run function – call this with your custom settings!
# -----------------------------------------------------------------
def run_optimizer(
    lock_chars=None,
    csv_path="genshin_data_export.csv",
    gcsim_bin="./gcsim",
    sim_duration=20,
    sim_iterations=150,
    population_size=100,
    generations=40,
    mutation_rate=0.15,
    crossover_rate=0.8,
    tournament_size=3,
    min_character_level=50,
    traveler_override=None,
    traveler_default="anemo",
    save_prefix="default",
    pareto=True               # Set to False for pure DPS optimisation (no Pareto archive)
):

    if traveler_override is None:
        traveler_override = {}
    # ---- Canonical gcsim data (kept inside to avoid global clutter) ----
    GCSIM_CHARACTER_KEYS = {
        'aino', 'albedo', 'alhaitham', 'aloy', 'amber', 'arlecchino', 'ayaka', 'ayato',
        'baizhu', 'barbara', 'beidou', 'bennett', 'candace', 'charlotte', 'chasca',
        'chevreuse', 'chiori', 'chongyun', 'citlali', 'clorinde', 'collei', 'columbina',
        'cyno', 'dahlia', 'dehya', 'diluc', 'diona', 'dori', 'emilie', 'escoffier', 'eula',
        'faruzan', 'fischl', 'flins', 'freminet', 'furina', 'gaming', 'ganyu', 'gorou',
        'heizou', 'hutao', 'ineffa', 'itto', 'jean', 'kaeya', 'kaveh', 'kazuha', 'keqing',
        'kinich', 'kirara', 'klee', 'kokomi', 'kuki', 'lanyan', 'lauma', 'layla', 'lisa',
        'lynette', 'lyney', 'mavuika', 'mika', 'mizuki', 'mona', 'mualani', 'nahida',
        'navia', 'neuvillette', 'nilou', 'ningguang', 'noelle', 'ororon', 'qiqi', 'raiden',
        'razor', 'rosaria', 'sara', 'sayu', 'sethos', 'shenhe', 'sigewinne', 'skirk',
        'sucrose', 'tartaglia', 'thoma', 'tighnari', 'varesa', 'venti', 'wanderer',
        'wriothesley', 'xiangling', 'xianyun', 'xiao', 'xilonen', 'xingqiu', 'xinyan',
        'yaemiko', 'yanfei', 'yaoyao', 'yelan', 'yoimiya', 'yunjin', 'zhongli',
    }
    TRAVELER_ELEMENTS = ('anemo', 'geo', 'electro', 'dendro', 'hydro', 'pyro', 'cryo')
    for _e in TRAVELER_ELEMENTS:
        GCSIM_CHARACTER_KEYS.add(f'aether{_e}')
        GCSIM_CHARACTER_KEYS.add(f'lumine{_e}')

    CHARACTER_NAME_OVERRIDES = {
        'kamisatoayaka': 'ayaka', 'kamisatoayato': 'ayato', 'raidenshogun': 'raiden',
        'sangonomiyakokomi': 'kokomi', 'kujousara': 'sara', 'kukishinobu': 'kuki',
        'shikanoinheizou': 'heizou', 'aratakiitto': 'itto', 'kaedeharakazuha': 'kazuha',
        'childe': 'tartaglia', 'scaramouche': 'wanderer', 'kusanali': 'nahida',
        'lesserlordkusanali': 'nahida',
    }

    # Full weapon/set/stat dictionaries
    GCSIM_WEAPON_KEYS = {
        'absolution', 'akuoumaru', 'alleyhunter', 'amenomakageuchi', 'amosbow', 'apprenticesnotes',
        'aquasimulacra', 'aquilafavonia', 'ashgravendrinkinghorn', 'astralvulturescrimsonplumage',
        'athousandblazingsuns', 'athousandfloatingdreams', 'azurelight', 'balladoftheboundlessblue',
        'balladofthefjords', 'beaconofthereedsea', 'beginnersprotector', 'blackcliffagate',
        'blackclifflongsword', 'blackcliffpole', 'blackcliffslasher', 'blackcliffwarbow',
        'blackmarrowlantern', 'blacktassel', 'bloodsoakedruins', 'bloodtaintedgreatsword',
        'calamityofeshu', 'calamityqueller', 'cashflowsupervision', 'chainbreaker', 'cinnabarspindle',
        'cloudforged', 'compoundbow', 'coolsteel', 'cranesechoingcall', 'crescentpike',
        'crimsonmoonssemblance', 'darkironsword', 'dawningfrost', 'deathmatch', 'debateclub',
        'dialoguesofthedesertsages', 'dodocotales', 'dragonsbane', 'dragonspinespear', 'dullblade',
        'earthshaker', 'elegyfortheend', 'emeraldorb', 'endoftheline', 'engulfinglightning',
        'etherlightspindlelute', 'everlastingmoonglow', 'eyeofperception', 'fadingtwilight',
        'fangofthemountainking', 'favoniuscodex', 'favoniusgreatsword', 'favoniuslance',
        'favoniussword', 'favoniuswarbow', 'ferrousshadow', 'festeringdesire', 'filletblade',
        'finaleofthedeep', 'fleuvecendreferryman', 'flowerwreathedfeathers', 'flowingpurity',
        'fluteofezpitzal', 'footprintoftherainbow', 'forestregalia', 'fracturedhalo', 'freedomsworn',
        'frostbearer', 'fruitfulhook', 'fruitoffulfillment', 'hakushinring', 'halberd', 'hamayumi',
        'harangeppakufutsu', 'harbingerofdawn', 'huntersbow', 'hunterspath', 'ibispiercer',
        'ironpoint', 'ironsting', 'jadefallssplendor', 'kagotsurubeisshin', 'kagurasverity',
        'katsuragikirinagamasa', 'keyofkhajnisut', 'kingssquire', 'kitaincrossspear',
        'lightoffoliarincision', 'lionsroar', 'lithicblade', 'lithicspear',
        'lostprayertothesacredwinds', 'lumidouceelegy', 'luxurioussealord', 'magicguide',
        'mailedflower', 'makhairaaquamarine', 'mappamare', 'masterkey', 'memoryofdust', 'messenger',
        'missivewindspear', 'mistsplitterreforged', 'mitternachtswaltz', 'moonpiercer',
        'moonweaversdawn', 'mountainbracingbolt', 'mouunsmoon', 'nightweaverslookingglass',
        'nocturnescurtaincall', 'oathsworneye', 'oldmercspal', 'otherworldlystory', 'peakpatrolsong',
        'pocketgrimoire', 'polarstar', 'portablepowersaw', 'predator', 'primordialjadecutter',
        'primordialjadewingedspear', 'prospectorsdrill', 'prospectorsshovel', 'prototypeamber',
        'prototypearchaic', 'prototypecrescent', 'prototyperancour', 'prototypestarglitter',
        'rainbowserpentbow', 'rainslasher', 'rangegauge', 'ravenbow', 'recurvebow',
        'redhornstonethresher', 'reliquaryoftruth', 'rightfulreward', 'ringofyaxche', 'royalbow',
        'royalgreatsword', 'royalgrimoire', 'royallongsword', 'royalspear', 'rust', 'sacrificersstaff',
        'sacrificialbow', 'sacrificialfragments', 'sacrificialgreatsword', 'sacrificialjade',
        'sacrificialsword', 'sapwoodblade', 'scionoftheblazingsun', 'seasonedhuntersbow',
        'sequenceofsolitude', 'serenityscall', 'serpentspine', 'sharpshootersoath',
        'silvershowerheartstrings', 'silversword', 'skyridergreatsword', 'skyridersword',
        'skywardatlas', 'skywardblade', 'skywardharp', 'skywardpride', 'skywardspine', 'slingshot',
        'snarehook', 'snowtombedstarsilver', 'solarpearl', 'songofbrokenpines', 'songofstillness',
        'splendoroftranquilwaters', 'staffofhoma', 'staffofthescarletsands', 'starcallerswatch',
        'sturdybone', 'summitshaper', 'sunnymorningsleepin', 'surfsup', 'swordofdescension',
        'swordofnarzissenkreuz', 'symphonistofscents', 'talkingstick', 'tamayurateinoohanashi',
        'thealleyflash', 'thebell', 'theblacksword', 'thecatch', 'thedockhandsassistant',
        'thefirstgreatmagic', 'theflute', 'thestringless', 'theunforged', 'theviridescenthunt',
        'thewidsith', 'thrillingtalesofdragonslayers', 'thunderingpulse', 'tidalshadow',
        'tomeoftheeternalflow', 'toukaboushigure', 'travelershandysword', 'tulaytullahsremembrance',
        'twinnephrite', 'ultimateoverlordsmegamagicsword', 'urakumisugiri', 'verdict', 'vividnotions',
        'vortexvanquisher', 'wanderingevenstar', 'wastergreatsword', 'wavebreakersfin',
        'waveridingwhirl', 'whiteblind', 'whiteirongreatsword', 'whitetassel', 'windblumeode',
        'wineandsong', 'wolffang', 'wolfsgravestone', 'xiphosmoonlight',
    }
    GCSIM_SET_KEYS = {
        'adventurer', 'archaicpetra', 'aubadeofmorningstarandmoon', 'berserker', 'blizzardstrayer',
        'bloodstainedchivalry', 'braveheart', 'crimsonwitchofflames', 'deepwoodmemories',
        'defenderswill', 'desertpavilionchronicle', 'echoesofanoffering', 'emblemofseveredfate',
        'finaleofthedeepgalleries', 'flowerofparadiselost', 'fragmentofharmonicwhimsy', 'gambler',
        'gildeddreams', 'gladiatorsfinale', 'goldentroupe', 'heartofdepth', 'huskofopulentdreams',
        'instructor', 'lavawalker', 'longnightsoath', 'luckydog', 'maidenbeloved',
        'marechausseehunter', 'martialartist', 'nightoftheskysunveiling',
        'nighttimewhispersintheechoingwoods', 'noblesseoblige', 'nymphsdream', 'obsidiancodex',
        'oceanhuedclam', 'paleflame', 'prayersfordestiny', 'prayersforillumination',
        'prayersforwisdom', 'prayerstospringtime', 'resolutionofsojourner', 'retracingbolide',
        'scholar', 'scrolloftheheroofcindercity', 'shimenawasreminiscence', 'silkenmoonsserenade',
        'songofdayspast', 'tenacityofthemillelith', 'theexile', 'thunderingfury', 'thundersoother',
        'tinymiracle', 'travelingdoctor', 'unfinishedreverie', 'vermillionhereafter',
        'viridescentvenerer', 'vourukashasglow', 'wandererstroupe',
    }
    FIGHT_PROP_TO_GCSIM = {
        'FIGHT_PROP_HP':                ('hp',       False),
        'FIGHT_PROP_HP_PERCENT':        ('hp%',      True),
        'FIGHT_PROP_ATTACK':            ('atk',      False),
        'FIGHT_PROP_ATTACK_PERCENT':    ('atk%',     True),
        'FIGHT_PROP_DEFENSE':           ('def',      False),
        'FIGHT_PROP_DEFENSE_PERCENT':   ('def%',     True),
        'FIGHT_PROP_CRITICAL':          ('cr',       True),
        'FIGHT_PROP_CRITICAL_HURT':     ('cd',       True),
        'FIGHT_PROP_CHARGE_EFFICIENCY': ('er',       True),
        'FIGHT_PROP_ELEMENT_MASTERY':   ('em',       False),
        'FIGHT_PROP_HEAL_ADD':          ('heal',     True),
        'FIGHT_PROP_FIRE_ADD_HURT':     ('pyro%',    True),
        'FIGHT_PROP_WATER_ADD_HURT':    ('hydro%',   True),
        'FIGHT_PROP_WIND_ADD_HURT':     ('anemo%',   True),
        'FIGHT_PROP_ICE_ADD_HURT':      ('cryo%',    True),
        'FIGHT_PROP_ELEC_ADD_HURT':     ('electro%', True),
        'FIGHT_PROP_GRASS_ADD_HURT':    ('dendro%',  True),
        'FIGHT_PROP_ROCK_ADD_HURT':     ('geo%',     True),
        'FIGHT_PROP_PHYSICAL_ADD_HURT': ('phys%',    True),
    }
    ELEMENT_DMG_PROP_TO_ELEMENT = {
        'FIGHT_PROP_FIRE_ADD_HURT':  'pyro',
        'FIGHT_PROP_WATER_ADD_HURT': 'hydro',
        'FIGHT_PROP_WIND_ADD_HURT':  'anemo',
        'FIGHT_PROP_ICE_ADD_HURT':   'cryo',
        'FIGHT_PROP_ELEC_ADD_HURT':  'electro',
        'FIGHT_PROP_GRASS_ADD_HURT': 'dendro',
        'FIGHT_PROP_ROCK_ADD_HURT':  'geo',
    }
    SUBSTAT_RE = re.compile(r'^([A-Z_]+)\+(-?[\d.]+)$')
    FILLER_ACTION = {
        'ganyu': 'aim',
        'neuvillette': 'charge',
    }

        # ---------- NEW CONSTANTS FOR ROTATION LEARNING ----------

        # ---------- NEW CONSTANTS FOR ROTATION LEARNING (CONDITIONALS) ----------
    # Basic actions
    SIMPLE_ACTIONS = [
        "skill", "burst",
        "attack:1", "attack:2", "attack:3", "attack:4", "attack:5",
        "charge", "aim",
    ]
    NUM_SIMPLE = len(SIMPLE_ACTIONS)             # 11

    # Complex conditional commands – each has variants (if parameterised)
    COMPLEX_COMMANDS = [
        # (name, num_variants, generator_function)
        ("energy_burst", 5, lambda slot, var:   # var 0..4 → thresholds 50,60,70,80,90
            f"if .{slot}.energy >= {50 + var*10} {{ {slot} burst; }}"),
                # ---------- NEW ----------
        ("energy_skill_low", 5, lambda slot, var:
            f"if .{slot}.energy < {50 + var*10} {{ {slot} skill; }}"),
        ("skill_ready",  1, lambda slot, var:
            f"if .{slot}.skill.ready {{ {slot} skill; }}"),
        #("cooldown_wait",1, lambda slot, var:
        #    f"while .{slot}.skill.cooldown > 0 {{ wait(1); }}"),
        #("wait",         8, lambda slot, var:   # var → frames: [5,10,15,20,30,40,50,60]
        #    f"wait({ [5,10,15,20,30,40,50,60][var] });"),
        #("cons_opener",  3, lambda slot, var:   # var → cons threshold: [1,2,4]
        #    f"if .{slot}.cons >= {[1,2,4][var]} {{ {slot} skill; {slot} burst; }} else {{ {slot} burst; {slot} skill; }}"),
    ]

    # Build total command list for encoding
    TOTAL_COMMANDS = NUM_SIMPLE + sum(num for _, num, _ in COMPLEX_COMMANDS)
    NOOP_TOKEN = TOTAL_COMMANDS * 4                     # 4 slots worth of tokens
    MAX_ROT_LEN = 80                                    # increased for complex rotations

    # Pre‑compute a list of (command_name, variant_offset) for decoding
    COMPLEX_OFFSET = NUM_SIMPLE
    COMPLEX_INFO = []           # each entry: (name, num_variants, variant_offset_start)
    offset = 0
    for name, num, _ in COMPLEX_COMMANDS:
        COMPLEX_INFO.append((name, num, COMPLEX_OFFSET + offset))
        offset += num                          # tunable length limit

    def decode_rotation(tokens):
        """Return list of (slot, gcsim_command_string)."""
        seq = []
        for t in tokens:
            if t >= NOOP_TOKEN:
                break
            slot = t // TOTAL_COMMANDS
            cmd_idx = t % TOTAL_COMMANDS
            if cmd_idx < NUM_SIMPLE:
                # Simple action
                cmd = SIMPLE_ACTIONS[cmd_idx]
                seq.append((slot, cmd))
            else:
                # Complex command
                # Find which complex command and variant
                for name, num, base in COMPLEX_INFO:
                    if base <= cmd_idx < base + num:
                        variant = cmd_idx - base
                        # Get the generator function
                        gen = next(g for n, cnt, g in COMPLEX_COMMANDS if n == name)
                        # We need the actual character key from the team when building config,
                        # so we store a placeholder here that will be replaced later.
                        # For now, store a special string with slot placeholder.
                        seq.append((slot, f"__COMPLEX__{name}__{variant}__"))
                        break
                else:
                    # Should never happen
                    seq.append((slot, "attack:1"))
        return seq
    # ---- Helper functions ----
    def _normalize(name):
        return re.sub(r"""[\s'".\-]""", "", str(name)).lower()

    def resolve_traveler(label, row, warnings):
        base = 'aether' if label.strip().lower() == 'aether' else 'lumine'
        if label in traveler_override:
            elem = traveler_override[label]
            warnings.append(f"{label}: using override element '{elem}'.")
            return f'{base}{elem}'
        for i in range(1, 6):
            main_type = row.get(f'Artifact {i} Main Stat Type')
            if pd.notna(main_type) and main_type in ELEMENT_DMG_PROP_TO_ELEMENT:
                elem = ELEMENT_DMG_PROP_TO_ELEMENT[main_type]
                warnings.append(f"{label}: auto-detected '{elem}' from goblet.")
                return f'{base}{elem}'
        for i in range(1, 6):
            for j in range(1, 5):
                sub = row.get(f'Artifact {i} Sub {j}')
                if pd.notna(sub):
                    for prop, elem in ELEMENT_DMG_PROP_TO_ELEMENT.items():
                        if str(sub).startswith(prop + '+'):
                            warnings.append(f"{label}: weak detection '{elem}' from substat.")
                            return f'{base}{elem}'
        warnings.append(f"{label}: defaulting to '{traveler_default}'.")
        return f'{base}{traveler_default}'

    def to_gcsim_name(csv_name, row, warnings):
        label = str(csv_name).strip()
        norm = _normalize(label)
        if norm in ('aether', 'lumine'):
            return resolve_traveler(label, row, warnings)
        if norm in CHARACTER_NAME_OVERRIDES:
            return CHARACTER_NAME_OVERRIDES[norm]
        if norm in GCSIM_CHARACTER_KEYS:
            return norm
        warnings.append(f"SKIPPED character '{label}': not in gcsim.")
        return None

    def to_gcsim_weapon(csv_weapon, char_label, warnings):
        norm = _normalize(csv_weapon)
        if norm in GCSIM_WEAPON_KEYS:
            return norm
        warnings.append(f"{char_label}: weapon '{csv_weapon}' not recognized.")
        return None

    def to_gcsim_set(csv_set, char_label, warnings):
        norm = _normalize(csv_set)
        if norm in GCSIM_SET_KEYS:
            return norm
        warnings.append(f"{char_label}: set '{csv_set}' not recognized.")
        return None

    def accumulate_artifact_stats(row, char_label, warnings):
        totals = {}
        unknown_types = set()

        def add(prop_type, raw_value):
            if prop_type not in FIGHT_PROP_TO_GCSIM:
                unknown_types.add(prop_type)
                return
            key, is_percent = FIGHT_PROP_TO_GCSIM[prop_type]
            v = raw_value / 100.0 if is_percent else raw_value
            totals[key] = totals.get(key, 0.0) + v

        for i in range(1, 6):
            main_type = row.get(f'Artifact {i} Main Stat Type')
            main_val = row.get(f'Artifact {i} Main Stat Value')
            if pd.notna(main_type) and pd.notna(main_val):
                add(str(main_type), float(main_val))
            for j in range(1, 5):
                sub = row.get(f'Artifact {i} Sub {j}')
                if pd.notna(sub):
                    m = SUBSTAT_RE.match(str(sub).strip())
                    if m:
                        add(m.group(1), float(m.group(2)))
                    else:
                        unknown_types.add(f"unparsable {sub!r}")
        if unknown_types:
            warnings.append(f"{char_label}: ignored unrecognized stat entries {sorted(unknown_types)}")
        return totals

    # ---- Build character configs ----
    def build_character_configs():
        df = pd.read_csv(csv_path, encoding='utf-8')
        df = df[df['Character Level'] >= min_character_level].copy()
        configs = {}
        skipped_unsupported = []
        warnings = []

        for _, row in df.iterrows():
            csv_name = row['Character Name']
            gcsim_name = to_gcsim_name(csv_name, row, warnings)
            if gcsim_name is None:
                skipped_unsupported.append(str(csv_name))
                continue

            char_label = f"{csv_name} -> {gcsim_name}"
            level = int(row['Character Level'])
            cons = int(row['Character Constellations']) if pd.notna(row.get('Character Constellations')) else 0
            na_raw = int(row['Talent NA Level']) if pd.notna(row.get('Talent NA Level')) else 1
            skill_raw = int(row['Talent Skill Level']) if pd.notna(row.get('Talent Skill Level')) else 1
            burst_raw = int(row['Talent Burst Level']) if pd.notna(row.get('Talent Burst Level')) else 1

            na, skill, burst = na_raw, skill_raw, burst_raw
            if cons >= 3 and skill > 10:
                skill = max(1, skill - 3)
                warnings.append(f"{char_label}: Skill boosted by C3, base {skill}.")
            if cons >= 5 and burst > 10:
                burst = max(1, burst - 3)
                warnings.append(f"{char_label}: Burst boosted by C5, base {burst}.")
            if na > 10:
                na = 10
                warnings.append(f"{char_label}: NA capped to 10.")
            na = max(1, min(10, na))
            skill = max(1, min(10, skill))
            burst = max(1, min(10, burst))

            lines = [
                f"{gcsim_name} char lvl={level}/90 cons={cons} talent={na},{skill},{burst} "
                f"+params=[start_energy=100];"
            ]
            weapon_name = row.get('Weapon Name')
            if pd.notna(weapon_name):
                weapon_key = to_gcsim_weapon(weapon_name, char_label, warnings)
                if weapon_key:
                    wlvl = int(row['Weapon Level']) if pd.notna(row.get('Weapon Level')) else 90
                    refine = int(row['Weapon Refinement']) if pd.notna(row.get('Weapon Refinement')) else 1
                    lines.append(f'{gcsim_name} add weapon="{weapon_key}" refine={refine} lvl={wlvl}/90;')
            set_counts = {}
            for i in range(1, 6):
                set_name = row.get(f'Artifact {i} Set')
                if pd.notna(set_name):
                    set_counts[set_name] = set_counts.get(set_name, 0) + 1
            for set_name, count in set_counts.items():
                if count < 2:
                    continue
                set_key = to_gcsim_set(set_name, char_label, warnings)
                if set_key:
                    lines.append(f'{gcsim_name} add set="{set_key}" count={count};')
            stat_totals = accumulate_artifact_stats(row, char_label, warnings)
            if stat_totals:
                stat_parts = [f'{k}={v:.4f}' for k, v in sorted(stat_totals.items())]
                lines.append(f'{gcsim_name} add stats {" ".join(stat_parts)};')
            if gcsim_name in configs:
                warnings.append(f"'{csv_name}' overwriting {gcsim_name}.")
            configs[gcsim_name] = '\n'.join(lines)

        print(f"Loaded {len(configs)} usable character(s): {sorted(configs.keys())}")
        if skipped_unsupported:
            print(f"\nSkipped {len(skipped_unsupported)} character(s) gcsim doesn't support yet:")
            for name in skipped_unsupported:
                print(f"  - {name}")
        if warnings:
            print(f"\n{len(warnings)} note(s)/warning(s):")
            for w in warnings:
                print(f"  - {w}")
        print()
        return configs

    char_configs = build_character_configs()
    all_chars = set(char_configs.keys())
    if lock_chars is None:
        lock_chars = []
    # Validate locked characters exist
    missing = [c for c in lock_chars if c not in all_chars]
    if missing:
        raise ValueError(f"Locked characters not in roster: {missing}")

    if len(all_chars) < 4:
        raise RuntimeError("Need at least 4 characters.")

    # ---- Rotation presets ----
    def preset_standard(team):
        """Burst all → Skill all → filler (attack:1) on first character."""
        seq = []
        for i in range(4):
            seq.append((i, "burst"))
        for i in range(4):
            seq.append((i, "skill"))
        seq.append((0, "attack:1"))
        return seq

    def preset_support_first(team):
        """Burst supports (first three) → Burst main DPS (fourth) → Skill all → filler."""
        seq = []
        for i in range(3):          # supports
            seq.append((i, "burst"))
        seq.append((3, "burst"))    # main DPS
        for i in range(4):
            seq.append((i, "skill"))
        seq.append((3, "attack:1")) # main DPS attacks
        return seq

    def preset_quickswap(team):
        """Skill all → Burst all → filler (attack:1) on first character."""
        seq = []
        for i in range(4):
            seq.append((i, "skill"))
        for i in range(4):
            seq.append((i, "burst"))
        seq.append((0, "attack:1"))
        return seq

    def preset_raiden_hyper(team):
        """Skill all → Burst all → if first is Raiden do attack:15 else attack:1."""
        seq = []
        for i in range(4):
            seq.append((i, "skill"))
        for i in range(4):
            seq.append((i, "burst"))
        if team[0] == "raiden":
            seq.append((0, "attack:15"))
        else:
            seq.append((0, "attack:1"))
        return seq

    def preset_ganyu_aimed(team):
        """Burst all → Skill all → if first is Ganyu aim else attack:1."""
        seq = []
        for i in range(4):
            seq.append((i, "burst"))
        for i in range(4):
            seq.append((i, "skill"))
        if team[0] == "ganyu":
            seq.append((0, "aim"))
        else:
            seq.append((0, "attack:1"))
        return seq

    def preset_wriothesley_charge(team):
        """Burst all → Skill all → if first is Wriothesley charge else attack:1."""
        seq = []
        for i in range(4):
            seq.append((i, "burst"))
        for i in range(4):
            seq.append((i, "skill"))
        if team[0] == "wriothesley":
            seq.append((0, "charge"))
        else:
            seq.append((0, "attack:1"))
        return seq

    def preset_universal_filler_heavy(team):   # ✅ correct name
        seq = []
        for i in range(4):
            seq.append((i, "burst"))
        for i in range(4):
            seq.append((i, "skill"))
        for _ in range(3):
            seq.append((0, "attack:1"))
        return seq

    def preset_burst_skill_weave(team):
        """Alternate Burst → Skill per character, then filler."""
        seq = []
        for i in range(4):
            seq.append((i, "burst"))
            seq.append((i, "skill"))
        seq.append((0, "attack:1"))
        return seq

    def preset_national(team):
        """Burst supports (first three) → Burst main DPS (fourth) → Skill all → filler."""
        # Same logic as support_first
        seq = []
        for i in range(3):
            seq.append((i, "burst"))
        seq.append((3, "burst"))
        for i in range(4):
            seq.append((i, "skill"))
        seq.append((3, "attack:1"))
        return seq

    def preset_hyperbloom_driver(team):
        """Burst all → Skill all → 6 normal attacks on first character."""
        seq = []
        for i in range(4):
            seq.append((i, "burst"))
        for i in range(4):
            seq.append((i, "skill"))
        for _ in range(6):
            seq.append((0, "attack:1"))
        return seq

    def preset_melt_ganyu_reverse(team):
        """Skill all → Burst all → if first is Ganyu aim else attack:1."""
        seq = []
        for i in range(4):
            seq.append((i, "skill"))
        for i in range(4):
            seq.append((i, "burst"))
        if team[0] == "ganyu":
            seq.append((0, "aim"))
        else:
            seq.append((0, "attack:1"))
        return seq

    def preset_battery_first(team):
        """Skill all → Burst all → filler (attack:1)."""
        seq = []
        for i in range(4):
            seq.append((i, "skill"))
        for i in range(4):
            seq.append((i, "burst"))
        seq.append((0, "attack:1"))
        return seq

    def preset_tanky(team):
        """Burst all → Skill all → 2 fillers (attack:1) on first character."""
        seq = []
        for i in range(4):
            seq.append((i, "burst"))
        for i in range(4):
            seq.append((i, "skill"))
        for _ in range(2):
            seq.append((0, "attack:1"))
        return seq

    def preset_kinich_skill(team):
        """Burst all → Skill all → if first is Kinich do attack:4 else attack:1."""
        seq = []
        for i in range(4):
            seq.append((i, "burst"))
        for i in range(4):
            seq.append((i, "skill"))
        if team[0] == "kinich":
            seq.append((0, "attack:4"))
        else:
            seq.append((0, "attack:1"))
        return seq


    ROTATION_PRESETS = [
    preset_standard,
    preset_support_first,
    preset_quickswap,
    preset_raiden_hyper,
    preset_ganyu_aimed,
    preset_wriothesley_charge,
    preset_universal_filler_heavy,
    preset_burst_skill_weave,
    preset_national,
    preset_hyperbloom_driver,
    preset_melt_ganyu_reverse,
    preset_battery_first,
    preset_tanky,
    preset_kinich_skill,
    ]

    def preset_to_tokens(preset_func, team):
        seq = preset_func(team)
        tokens = []
        for slot, cmd in seq:
            if cmd in SIMPLE_ACTIONS:
                tokens.append(slot * TOTAL_COMMANDS + SIMPLE_ACTIONS.index(cmd))
        # pad/truncate to MAX_ROT_LEN
        if len(tokens) > MAX_ROT_LEN:
            tokens = tokens[:MAX_ROT_LEN]
        else:
            tokens += [NOOP_TOKEN] * (MAX_ROT_LEN - len(tokens))
        return tokens

    def build_full_config(team, rotation_tokens):
        seq = decode_rotation(rotation_tokens)
        if not seq:
            seq = [(0, "attack:1")]

        first_slot = seq[0][0]
        active_char = team[first_slot]

        config = f"""
options iteration={sim_iterations} duration={sim_duration} swap_delay=4;
target lvl=100 resist=0.1 particle_threshold=250000 particle_drop_count=1;

"""
        for name in team:
            config += char_configs[name] + '\n'

        config += f'active {active_char};\n\n'
        config += 'while 1 {\n'

        for slot, cmd in seq:
            if cmd.startswith("__COMPLEX__"):
                # Extract name and variant
                parts = cmd.split("__")
                name = parts[2]
                variant = int(parts[3])
                # Find generator and call with real character key
                for cname, _, gen in COMPLEX_COMMANDS:
                    if cname == name:
                        line = gen(team[slot], variant)
                        config += f'  {line}\n'   # already contains newlines? no, it's one line but may have braces.
                        break
            else:
                char = team[slot]
                config += f'  {char} {cmd};\n'
        config += '}\n'
        return config
    # ---- Run gcsim and return objectives dict ----
    def run_gcsim(config_str):
        with tempfile.NamedTemporaryFile(mode='w', suffix='.txt', delete=False) as f:
            f.write(config_str)
            config_path = f.name
        output_path = config_path + '.json'
        try:
            result = subprocess.run(
                [gcsim_bin, '-c', config_path, '-out', output_path],
                capture_output=True, text=True, timeout=120
            )
            if result.returncode != 0:
                return {'dps': 0.0, 'max_hit': 0.0, 'sd': 0.0}
            with open(output_path, 'r') as jf:
                data = json.load(jf)
            stats = data['statistics']
            dps = stats['dps']['mean']
            sd = stats['dps']['sd']

            # Extract max single hit from damage buckets
            max_hit = 0.0
            buckets_info = stats.get('damage_buckets')
            if buckets_info:
                bucket_list = buckets_info.get('buckets', [])
                for bucket in bucket_list:
                    if isinstance(bucket, dict):
                        raw = bucket.get('max', 0.0)
                        # Sometimes gcsim nests the value inside a dict
                        if isinstance(raw, dict):
                            raw = raw.get('value', 0.0)
                        # Ensure we have a number
                        try:
                            val = float(raw)
                            if val > max_hit:
                                max_hit = val
                        except (TypeError, ValueError):
                            pass   # ignore non‑numeric junk

            # Fallback to total_damage – it can also be a dict
            if max_hit == 0.0:
                total_raw = stats.get('total_damage', 0.0)
                if isinstance(total_raw, dict):
                    total_raw = total_raw.get('value', 0.0)
                try:
                    max_hit = float(total_raw)
                except (TypeError, ValueError):
                    max_hit = 0.0

            return {'dps': dps, 'max_hit': max_hit, 'sd': sd}
        except Exception as e:
            import sys
            print(f"Exception in run_gcsim: {e}", file=sys.stderr)
            return {'dps': 0.0, 'max_hit': 0.0, 'sd': 0.0}
        finally:
            for f in [config_path, output_path]:
                if os.path.exists(f):
                    os.unlink(f)
    def ensure_valid_individual(ind):
        team, rot = ind
        # Force team to be 4 unique characters with lock_chars respected
        team = repair_team(list(team))
        return (team, rot)
    # ---- EA functions ----
    def random_team():
        locked = list(lock_chars)
        random.shuffle(locked)
        needed = 4 - len(locked)
        others = random.sample(list(all_chars - set(locked)), needed)
        team = locked + others
        random.shuffle(team)
        return tuple(team)
    def create_individual():
        team = random_team()
        if random.random() < 0.8:
            preset_func = random.choice(ROTATION_PRESETS)
            rot = preset_to_tokens(preset_func, team)
        else:
            # Random rotation – mix simple and complex commands
            length = random.randint(5, MAX_ROT_LEN)
            rot = []
            for _ in range(length):
                if random.random() < 0.3:   # 30% chance of complex command
                    # pick a random complex command and variant
                    cname, num_var, _ = random.choice(COMPLEX_COMMANDS)
                    cmd_idx = COMPLEX_OFFSET + sum(n for name, n, _ in COMPLEX_COMMANDS if name < cname)
                    cmd_idx += random.randrange(num_var)
                else:
                    cmd_idx = random.randrange(NUM_SIMPLE)
                slot = random.randrange(4)
                rot.append(slot * TOTAL_COMMANDS + cmd_idx)
            rot += [NOOP_TOKEN] * (MAX_ROT_LEN - length)
        return (team, rot)
    def fitness(individual):
        team, rot = individual
        config = build_full_config(team, rot)
        return run_gcsim(config)
    def tournament_selection(population, scores):
        selected = random.sample(list(zip(population, scores)), tournament_size)
        selected.sort(key=lambda x: x[1]['dps'], reverse=True)
        return selected[0][0]

    def repair_team(team_list):
        """Ensure exactly 4 unique chars, lock_chars present once, no duplicates."""
        locked_set = set(lock_chars)

        # 1. Keep only the first occurrence of each locked char
        seen = {}
        for i, c in enumerate(team_list):
            if c in locked_set and c not in seen:
                seen[c] = i
            else:
                # mark for removal if duplicate locked or locked not in lock_chars
                pass   # we'll rebuild cleanly

        # 2. Build a clean list of 4 slots, starting with locked chars
        result = [None, None, None, None]
        # Place each locked char exactly once (shuffle positions among first 4)
        locked_indices = list(range(4))
        random.shuffle(locked_indices)
        for lc in locked_set:
            idx = locked_indices.pop()
            result[idx] = lc

        # 3. Fill remaining slots with unique non‑locked chars from the original list + random
        # Collect candidate non‑locked chars that are in the original list (avoiding duplicates)
        original_nonlocked = [c for c in team_list if c not in locked_set]
        random.shuffle(original_nonlocked)
        # Use set to avoid duplicates, but preserve order
        nonlocked_unique = []
        for c in original_nonlocked:
            if c not in nonlocked_unique and c not in result:
                nonlocked_unique.append(c)

        empty_slots = [i for i, val in enumerate(result) if val is None]
        random.shuffle(empty_slots)

        # First use the unique non‑locked chars from the original
        for slot in empty_slots:
            if nonlocked_unique:
                result[slot] = nonlocked_unique.pop(0)
            else:
                # Pick a random new character not already in the team and not locked
                available = list(all_chars - set(result) - locked_set)
                if available:
                    result[slot] = random.choice(available)
                else:
                    # Fallback (should never happen if roster size >= 4)
                    result[slot] = random.choice(list(all_chars))

        # Final safety: ensure no None and all unique
        for i in range(4):
            if result[i] is None or (result.count(result[i]) > 1):
                # Brute‑force fill with unique char
                taken = set(result)
                available = list(all_chars - taken)
                if available:
                    result[i] = random.choice(available)
                else:
                    result[i] = random.choice(list(all_chars))

        return tuple(result)
    def crossover_team(t1, t2):
        child = [t1[i] if random.random() < 0.5 else t2[i] for i in range(4)]
        return repair_team(child)

    def crossover_rotation(r1, r2):
        point = random.randint(1, MAX_ROT_LEN - 1)
        return r1[:point] + r2[point:]

    def mutate_team(team):
        if random.random() >= mutation_rate:
            return team
        mutable = [i for i in range(4) if team[i] not in lock_chars]
        if not mutable:
            return team
        idx = random.choice(mutable)
        available = [c for c in all_chars if c not in team]
        if available:
            team_list = list(team)
            team_list[idx] = random.choice(available)
            return repair_team(team_list)   # ← MUST HAVE THIS
        return team
    def mutate_rotation(tokens):
        tokens = tokens[:]
        for i in range(MAX_ROT_LEN):
            if random.random() < 0.05:            # replace token entirely
                if random.random() < 0.5:         # with simple
                    tokens[i] = random.randrange(4) * TOTAL_COMMANDS + random.randrange(NUM_SIMPLE)
                else:                              # with complex
                    cname, num_var, _ = random.choice(COMPLEX_COMMANDS)
                    base = COMPLEX_OFFSET + sum(n for name, n, _ in COMPLEX_COMMANDS if name < cname)
                    cmd_idx = base + random.randrange(num_var)
                    tokens[i] = random.randrange(4) * TOTAL_COMMANDS + cmd_idx
            elif random.random() < 0.02:          # insert & shift
                if random.random() < 0.5:
                    new_token = random.randrange(4) * TOTAL_COMMANDS + random.randrange(NUM_SIMPLE)
                else:
                    cname, num_var, _ = random.choice(COMPLEX_COMMANDS)
                    base = COMPLEX_OFFSET + sum(n for name, n, _ in COMPLEX_COMMANDS if name < cname)
                    cmd_idx = base + random.randrange(num_var)
                    new_token = random.randrange(4) * TOTAL_COMMANDS + cmd_idx
                tokens.insert(i, new_token)
                tokens.pop()
            elif random.random() < 0.01:          # mutate a complex token’s variant
                if tokens[i] < NOOP_TOKEN:
                    cmd_idx = tokens[i] % TOTAL_COMMANDS
                    if cmd_idx >= COMPLEX_OFFSET:
                        # find which complex command and shift variant
                        for name, num, base in COMPLEX_INFO:
                            if base <= cmd_idx < base + num:
                                current_var = cmd_idx - base
                                new_var = (current_var + random.choice([-1,1])) % num
                                tokens[i] = (tokens[i] // TOTAL_COMMANDS) * TOTAL_COMMANDS + base + new_var
                                break
        if random.random() < 0.1:                 # swap adjacent
            i = random.randint(0, MAX_ROT_LEN - 2)
            tokens[i], tokens[i+1] = tokens[i+1], tokens[i]
        return tokens

    def crossover(ind1, ind2):
        t1, r1 = ind1
        t2, r2 = ind2
        new_team = crossover_team(t1, t2)
        new_rot  = crossover_rotation(r1, r2)
        return (new_team, new_rot)

    def mutate(ind):
        team, rot = ind
        team = mutate_team(team)
        rot = mutate_rotation(rot)
        return (team, rot)
    def dominates(a, b):
        better = False
        if a['dps'] > b['dps']: better = True
        elif a['dps'] < b['dps']: return False
        if a['max_hit'] > b['max_hit']: better = True
        elif a['max_hit'] < b['max_hit']: return False
        if a['sd'] < b['sd']: better = True
        elif a['sd'] > b['sd']: return False
        return better
    def population_diversity(population):
        """Return dict with team_uniqueness, rot_div, and action_entropy."""
        # Team uniqueness
        teams = [team for team, _ in population]
        unique_teams = len(set(teams))
        team_uniq = unique_teams / len(population)

        # Rotation diversity (average pairwise Hamming distance)
        rot_tokens = [tuple(rot) for _, rot in population]
        n = len(rot_tokens)
        if n < 2:
            rot_div = 0.0
        else:
            total_dist = 0
            for i in range(n):
                for j in range(i+1, n):
                    total_dist += sum(1 for a, b in zip(rot_tokens[i], rot_tokens[j]) if a != b)
            max_pairs = n * (n-1) / 2
            rot_div = (total_dist / max_pairs) / MAX_ROT_LEN   # normalised

        # Action entropy (over all tokens in the population)
        from collections import Counter
        counter = Counter()
        total_tokens = 0
        for _, rot in population:
            for t in rot:
                if t < NOOP_TOKEN:
                    counter[t] += 1
                    total_tokens += 1
        import math
        entropy = 0.0
        if total_tokens > 0:
            for count in counter.values():
                p = count / total_tokens
                if p > 0:
                    entropy -= p * math.log2(p)

        return {
            'team_uniqueness': team_uniq,
            'rotation_diversity': rot_div,
            'action_entropy': entropy
        }

    # ---- CREATE OUTPUT FOLDER (per run) ----
    root_output = "optimizer_results"
    os.makedirs(root_output, exist_ok=True)
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    run_dir = os.path.join(root_output, f"{save_prefix}_{timestamp}")
    os.makedirs(run_dir, exist_ok=True)
    print(f"Output folder: {run_dir}")

    def save_file(filename, content):
        filepath = os.path.join(run_dir, filename)
        with open(filepath, 'w') as f:
            f.write(content)
        return filepath

    # ---- Main EA loop ----
    population = [create_individual() for _ in range(population_size)]
    best_overall = (None, {'dps': 0.0, 'max_hit': 0.0, 'sd': 0.0})
    pareto_archive = []   # only used if pareto=True

    mode_str = "Pareto multi‑objective" if pareto else "pure DPS"
    print(f"Starting EA: pop={population_size}, gen={generations}, duration={sim_duration}s, iterations={sim_iterations}, mode={mode_str}")

    # Quick debug
    debug_team = create_individual()
    test_res = fitness(debug_team)
    print(f"Debug team DPS: {test_res['dps']:.0f}, max_hit: {test_res['max_hit']:.0f}")

    try:
        for gen in range(generations):
            print(f"\nGeneration {gen+1}/{generations}")
            scores = [fitness(ind) for ind in population]
            unique_teams = set((team, tuple(rot)) for team, rot in population)
            print(f"Unique individuals: {len(unique_teams)}/{population_size}")

            div = population_diversity(population)
            print(f"Diversity: team_uniq={div['team_uniqueness']:.2f}, "
                  f"rot_div={div['rotation_diversity']:.2f}, "
                  f"action_entropy={div['action_entropy']:.1f}")

            # Update Pareto archive only if enabled
            if pareto:
                for team, obj in zip(population, scores):
                    dominated = False
                    for _, aobj in pareto_archive:
                        if dominates(aobj, obj):
                            dominated = True
                            break
                    if not dominated:
                        pareto_archive = [(t, o) for t, o in pareto_archive if not dominates(obj, o)]
                        pareto_archive.append((team, obj))

            fitness_vals = [s['dps'] for s in scores]
            top_indices = sorted(range(len(fitness_vals)), key=lambda i: fitness_vals[i], reverse=True)[:5]
            print("Top 5 this gen:")

            for idx in top_indices:
                team, rot = population[idx]
                seq = decode_rotation(rot)
                rot_len = len(seq)
                obj = scores[idx]
                print(f"  team:{team} rot_len:{rot_len} DPS:{obj['dps']:.0f} MaxHit:{obj['max_hit']:.0f}")
            best_idx = fitness_vals.index(max(fitness_vals))
            best_team, best_rot = population[best_idx]          # unpack chromosome
            best_obj = scores[best_idx]
            if best_obj['dps'] > best_overall[1]['dps']:
                best_overall = ((best_team, best_rot), best_obj) # store both parts

            print(f"Gen best: team={best_team} rot_len={len(decode_rotation(best_rot))} DPS:{best_obj['dps']:.0f} MaxHit:{best_obj['max_hit']:.0f}")
            print(f"Overall best: team={best_overall[0][0]} rot_len={len(decode_rotation(best_overall[0][1]))} DPS:{best_overall[1]['dps']:.0f} MaxHit:{best_overall[1]['max_hit']:.0f}")

            elite_count = max(1, int(population_size * 0.2))
            combined = sorted(zip(population, fitness_vals), key=lambda x: x[1], reverse=True)
            elites = [ind for ind, _ in combined[:elite_count]]
            new_pop = elites.copy()

            while len(new_pop) < population_size:
                p1 = tournament_selection(population, scores)
                p2 = tournament_selection(population, scores)
                if random.random() < crossover_rate:
                    child = crossover(p1, p2)
                else:
                    child = p1
                child = mutate(child)
                new_pop.append(child)
                        # ---- Guarantee every individual is valid ----
            new_pop = [ensure_valid_individual(ind) for ind in new_pop]
            population = new_pop
            for t, r in new_pop:
                assert len(set(t)) == 4, f"INVALID TEAM: {t}"

    except KeyboardInterrupt:
        print("\nInterrupted! Saving best so far.")


        if best_overall[0] is not None:
            best_team, best_rot = best_overall[0]
            config = build_full_config(best_team, best_rot)
            save_file("best_team_interrupted.txt", config)
        if pareto and pareto_archive:
            pareto_sorted = sorted(pareto_archive, key=lambda x: x[1]['dps'], reverse=True)[:10]
            for i, (t, obj) in enumerate(pareto_sorted):
                team, rot = t
                config = build_full_config(team, rot)
                save_file(f"pareto_interrupted_{i+1}.txt", config)
        raise

    # Final output
    print("\n===== FINAL BEST TEAM (by DPS) =====")
    best_obj = best_overall[1]
    best_team, best_rot = best_overall[0]
    best_config = build_full_config(best_team, best_rot)
    print(f"DPS: {best_obj['dps']:.0f}  MaxHit: {best_obj['max_hit']:.0f}")
    print(best_config)
    save_file("best_team.txt", best_config)

    if pareto and pareto_archive:
        print("\n===== PARETO FRONT (top 10) =====")
        pareto_archive.sort(key=lambda x: x[1]['dps'], reverse=True)
        top_10_pareto = pareto_archive[:10]
        for i, (ind, obj) in enumerate(top_10_pareto):
            team, rot = ind
            seq = decode_rotation(rot)
            rot_len = len(seq)
            print(f"#{i+1} team:{team} rot_len:{rot_len}")
            print(f"   DPS:{obj['dps']:.0f}  MaxHit:{obj['max_hit']:.0f}  SD:{obj['sd']:.0f}")
            config = build_full_config(team, rot)
            save_file(f"pareto_{i+1}.txt", config)
        # Save a JSON summary of the Pareto front
        summary = []
        for ind, obj in top_10_pareto:
            team, rot = ind
            summary.append({
                'team': list(team),
                'rotation_tokens': list(rot),
                'rotation_decoded': [(t // TOTAL_COMMANDS, SIMPLE_ACTIONS[t % TOTAL_COMMANDS]) if (t % TOTAL_COMMANDS) < NUM_SIMPLE else ("complex", t) for t in rot if t < NOOP_TOKEN],
                'dps': obj['dps'],
                'max_hit': obj['max_hit'],
                'sd': obj['sd']
            })
        with open(os.path.join(run_dir, 'pareto_summary.json'), 'w') as f:
            json.dump(summary, f, indent=2)
    else:
        print("\n(Pareto archive disabled – only the single best DPS team is shown)")

# %%
# ---- Call the function with your desired settings ----
if __name__ == "__main__":
    # Example 1: multi‑objective (Pareto) – you get best DPS + nuke + consistent teams
    run_optimizer(
        lock_chars=[],
        csv_path="genshin_data_export.csv",
        gcsim_bin="./gcsim",
        sim_duration=100,
        sim_iterations=1,
        population_size=50,
        generations=50,
        mutation_rate=0.4,
        save_prefix="general",
        pareto=True          # <-- this enables the Pareto front
    )

    # Example 2: pure DPS – only the team with the highest average DPS matters
    # run_optimizer(
    #     lock_chars=["neuvillette", "furina"],
    #     csv_path="genshin_data_export.csv",
    #     gcsim_bin="./gcsim",
    #     sim_duration=90,
    #     generations=50,
    #     population_size=150,
    #     save_prefix="pure_dps_test",
    #     pareto=False
    # )
# Out:
# Loaded 35 usable character(s): ['aetherdendro', 'ayato', 'barbara', 'beidou', 'bennett', 'charlotte', 'chevreuse', 'chongyun', 'citlali', 'collei', 'diona', 'fischl', 'furina', 'ganyu', 'heizou', 'jean', 'kinich', 'kuki', 'mavuika', 'mona', 'navia', 'neuvillette', 'ningguang', 'raiden', 'rosaria', 'sara', 'skirk', 'sucrose', 'venti', 'wriothesley', 'xiangling', 'xingqiu', 'yanfei', 'yelan', 'yunjin']
#
# Skipped 3 character(s) gcsim doesn't support yet:
#   - Nicole
#   - Durin
#   - Iansan
#
# 7 note(s)/warning(s):
#   - SKIPPED character 'Nicole': not in gcsim.
#   - SKIPPED character 'Durin': not in gcsim.
#   - Xingqiu -> xingqiu: Skill boosted by C3, base 8.
#   - Bennett -> bennett: Burst boosted by C5, base 8.
#   - Diona -> diona: Skill boosted by C3, base 8.
#   - SKIPPED character 'Iansan': not in gcsim.
#   - Aether: auto-detected 'dendro' from goblet.
#
# Output folder: optimizer_results/general_20260618_145613
# Starting EA: pop=50, gen=50, duration=100s, iterations=1, mode=Pareto multi‑objective
# Debug team DPS: 5666, max_hit: 38920
#
# Generation 1/50
# Unique individuals: 46/50
# Diversity: team_uniq=0.42, rot_div=0.37, action_entropy=5.6
# Top 5 this gen:
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:9 DPS:11545 MaxHit:51067
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:9 DPS:10849 MaxHit:49224
#   team:('neuvillette', 'fischl', 'jean', 'furina') rot_len:9 DPS:10653 MaxHit:51735
#   team:('fischl', 'furina', 'neuvillette', 'jean') rot_len:9 DPS:10590 MaxHit:39404
#   team:('fischl', 'furina', 'neuvillette', 'jean') rot_len:9 DPS:10382 MaxHit:47305
# Gen best: team=('fischl', 'neuvillette', 'furina', 'jean') rot_len=9 DPS:11545 MaxHit:51067
# Overall best: team=('fischl', 'neuvillette', 'furina', 'jean') rot_len=9 DPS:11545 MaxHit:51067
#
# Generation 2/50
# Unique individuals: 48/50
# Diversity: team_uniq=0.42, rot_div=0.19, action_entropy=4.9
# Top 5 this gen:
#   team:('jean', 'fischl', 'furina', 'neuvillette') rot_len:10 DPS:16876 MaxHit:45812
#   team:('neuvillette', 'fischl', 'furina', 'jean') rot_len:9 DPS:14882 MaxHit:51067
#   team:('neuvillette', 'fischl', 'jean', 'furina') rot_len:9 DPS:12281 MaxHit:48625
#   team:('furina', 'jean', 'neuvillette', 'fischl') rot_len:10 DPS:12194 MaxHit:48641
#   team:('neuvillette', 'fischl', 'furina', 'jean') rot_len:9 DPS:11325 MaxHit:42767
# Gen best: team=('jean', 'fischl', 'furina', 'neuvillette') rot_len=10 DPS:16876 MaxHit:45812
# Overall best: team=('jean', 'fischl', 'furina', 'neuvillette') rot_len=10 DPS:16876 MaxHit:45812
#
# Generation 3/50
# Unique individuals: 48/50
# Diversity: team_uniq=0.40, rot_div=0.20, action_entropy=5.2
# Top 5 this gen:
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:9 DPS:14610 MaxHit:44408
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:9 DPS:14303 MaxHit:56388
#   team:('neuvillette', 'fischl', 'jean', 'furina') rot_len:10 DPS:14221 MaxHit:39227
#   team:('jean', 'neuvillette', 'fischl', 'furina') rot_len:11 DPS:14217 MaxHit:46245
#   team:('jean', 'fischl', 'neuvillette', 'furina') rot_len:10 DPS:12746 MaxHit:48000
# Gen best: team=('fischl', 'furina', 'jean', 'neuvillette') rot_len=9 DPS:14610 MaxHit:44408
# Overall best: team=('jean', 'fischl', 'furina', 'neuvillette') rot_len=10 DPS:16876 MaxHit:45812
#
# Generation 4/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.42, rot_div=0.28, action_entropy=5.5
# Top 5 this gen:
#   team:('furina', 'neuvillette', 'fischl', 'jean') rot_len:10 DPS:17410 MaxHit:54367
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:10 DPS:16191 MaxHit:44183
#   team:('neuvillette', 'fischl', 'jean', 'furina') rot_len:11 DPS:15697 MaxHit:65496
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:9 DPS:15023 MaxHit:51087
#   team:('jean', 'furina', 'neuvillette', 'fischl') rot_len:10 DPS:14533 MaxHit:31450
# Gen best: team=('furina', 'neuvillette', 'fischl', 'jean') rot_len=10 DPS:17410 MaxHit:54367
# Overall best: team=('furina', 'neuvillette', 'fischl', 'jean') rot_len=10 DPS:17410 MaxHit:54367
#
# Generation 5/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.38, rot_div=0.36, action_entropy=5.6
# Top 5 this gen:
#   team:('neuvillette', 'jean', 'furina', 'fischl') rot_len:9 DPS:20092 MaxHit:42483
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:10 DPS:19395 MaxHit:52001
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:10 DPS:18584 MaxHit:45209
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:10 DPS:18276 MaxHit:37871
#   team:('furina', 'jean', 'fischl', 'neuvillette') rot_len:10 DPS:17311 MaxHit:55247
# Gen best: team=('neuvillette', 'jean', 'furina', 'fischl') rot_len=9 DPS:20092 MaxHit:42483
# Overall best: team=('neuvillette', 'jean', 'furina', 'fischl') rot_len=9 DPS:20092 MaxHit:42483
#
# Generation 6/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.46, rot_div=0.39, action_entropy=5.6
# Top 5 this gen:
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:10 DPS:19015 MaxHit:44233
#   team:('fischl', 'furina', 'neuvillette', 'jean') rot_len:10 DPS:15856 MaxHit:41651
#   team:('neuvillette', 'furina', 'jean', 'fischl') rot_len:10 DPS:15370 MaxHit:33631
#   team:('neuvillette', 'furina', 'fischl', 'jean') rot_len:11 DPS:15147 MaxHit:58159
#   team:('jean', 'fischl', 'neuvillette', 'furina') rot_len:10 DPS:14991 MaxHit:41424
# Gen best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=10 DPS:19015 MaxHit:44233
# Overall best: team=('neuvillette', 'jean', 'furina', 'fischl') rot_len=9 DPS:20092 MaxHit:42483
#
# Generation 7/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.42, action_entropy=5.6
# Top 5 this gen:
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:10 DPS:18668 MaxHit:41346
#   team:('furina', 'jean', 'fischl', 'neuvillette') rot_len:10 DPS:18159 MaxHit:49010
#   team:('furina', 'neuvillette', 'fischl', 'jean') rot_len:11 DPS:17324 MaxHit:48032
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:11 DPS:16699 MaxHit:34619
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:10 DPS:16318 MaxHit:44203
# Gen best: team=('fischl', 'neuvillette', 'jean', 'furina') rot_len=10 DPS:18668 MaxHit:41346
# Overall best: team=('neuvillette', 'jean', 'furina', 'fischl') rot_len=9 DPS:20092 MaxHit:42483
#
# Generation 8/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.40, rot_div=0.48, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:11 DPS:22373 MaxHit:50015
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:10 DPS:20103 MaxHit:54054
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:11 DPS:17553 MaxHit:42141
#   team:('jean', 'furina', 'neuvillette', 'fischl') rot_len:11 DPS:16220 MaxHit:46346
#   team:('fischl', 'furina', 'neuvillette', 'jean') rot_len:10 DPS:16106 MaxHit:39364
# Gen best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 9/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.42, rot_div=0.53, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:12 DPS:20104 MaxHit:35685
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:10 DPS:20099 MaxHit:45920
#   team:('furina', 'neuvillette', 'fischl', 'jean') rot_len:10 DPS:17643 MaxHit:45427
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:11 DPS:17321 MaxHit:58815
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:10 DPS:16934 MaxHit:41424
# Gen best: team=('fischl', 'jean', 'furina', 'neuvillette') rot_len=12 DPS:20104 MaxHit:35685
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 10/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.57, action_entropy=5.8
# Top 5 this gen:
#   team:('fischl', 'furina', 'neuvillette', 'jean') rot_len:14 DPS:20660 MaxHit:51383
#   team:('furina', 'neuvillette', 'fischl', 'jean') rot_len:10 DPS:18591 MaxHit:48234
#   team:('furina', 'neuvillette', 'fischl', 'jean') rot_len:10 DPS:18330 MaxHit:48234
#   team:('furina', 'jean', 'neuvillette', 'fischl') rot_len:11 DPS:17428 MaxHit:48752
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:10 DPS:16987 MaxHit:37152
# Gen best: team=('fischl', 'furina', 'neuvillette', 'jean') rot_len=14 DPS:20660 MaxHit:51383
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 11/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.38, rot_div=0.61, action_entropy=5.8
# Top 5 this gen:
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:14 DPS:21065 MaxHit:40198
#   team:('furina', 'neuvillette', 'fischl', 'jean') rot_len:10 DPS:20617 MaxHit:46842
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:14 DPS:19818 MaxHit:37624
#   team:('furina', 'jean', 'fischl', 'neuvillette') rot_len:14 DPS:19265 MaxHit:37624
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:14 DPS:19138 MaxHit:43171
# Gen best: team=('fischl', 'neuvillette', 'furina', 'jean') rot_len=14 DPS:21065 MaxHit:40198
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 12/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.65, action_entropy=5.8
# Top 5 this gen:
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:13 DPS:21065 MaxHit:57307
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:14 DPS:20602 MaxHit:38723
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:14 DPS:19876 MaxHit:38570
#   team:('furina', 'fischl', 'neuvillette', 'jean') rot_len:14 DPS:18112 MaxHit:47645
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:13 DPS:17804 MaxHit:45209
# Gen best: team=('fischl', 'neuvillette', 'jean', 'furina') rot_len=13 DPS:21065 MaxHit:57307
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 13/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.66, action_entropy=5.8
# Top 5 this gen:
#   team:('fischl', 'furina', 'neuvillette', 'jean') rot_len:14 DPS:20099 MaxHit:41755
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:13 DPS:18992 MaxHit:38106
#   team:('fischl', 'furina', 'neuvillette', 'jean') rot_len:14 DPS:18254 MaxHit:52781
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:14 DPS:18046 MaxHit:39018
#   team:('furina', 'fischl', 'neuvillette', 'jean') rot_len:16 DPS:17324 MaxHit:55832
# Gen best: team=('fischl', 'furina', 'neuvillette', 'jean') rot_len=14 DPS:20099 MaxHit:41755
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 14/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.40, rot_div=0.70, action_entropy=5.8
# Top 5 this gen:
#   team:('jean', 'furina', 'fischl', 'neuvillette') rot_len:15 DPS:20552 MaxHit:41865
#   team:('furina', 'neuvillette', 'jean', 'fischl') rot_len:14 DPS:19047 MaxHit:39996
#   team:('neuvillette', 'jean', 'furina', 'fischl') rot_len:16 DPS:17639 MaxHit:52534
#   team:('furina', 'jean', 'neuvillette', 'fischl') rot_len:13 DPS:17586 MaxHit:48823
#   team:('furina', 'fischl', 'neuvillette', 'jean') rot_len:17 DPS:16408 MaxHit:57172
# Gen best: team=('jean', 'furina', 'fischl', 'neuvillette') rot_len=15 DPS:20552 MaxHit:41865
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 15/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.42, rot_div=0.73, action_entropy=5.8
# Top 5 this gen:
#   team:('furina', 'neuvillette', 'jean', 'fischl') rot_len:14 DPS:18956 MaxHit:55642
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:14 DPS:17914 MaxHit:38790
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:13 DPS:17524 MaxHit:51067
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:13 DPS:17337 MaxHit:37927
#   team:('neuvillette', 'fischl', 'furina', 'jean') rot_len:18 DPS:16706 MaxHit:46474
# Gen best: team=('furina', 'neuvillette', 'jean', 'fischl') rot_len=14 DPS:18956 MaxHit:55642
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 16/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.40, rot_div=0.76, action_entropy=5.8
# Top 5 this gen:
#   team:('furina', 'neuvillette', 'jean', 'fischl') rot_len:14 DPS:21576 MaxHit:50226
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:14 DPS:19870 MaxHit:43853
#   team:('furina', 'neuvillette', 'jean', 'fischl') rot_len:13 DPS:18726 MaxHit:52889
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:17 DPS:16287 MaxHit:40417
#   team:('neuvillette', 'fischl', 'jean', 'furina') rot_len:16 DPS:16104 MaxHit:62698
# Gen best: team=('furina', 'neuvillette', 'jean', 'fischl') rot_len=14 DPS:21576 MaxHit:50226
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 17/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.42, rot_div=0.79, action_entropy=5.8
# Top 5 this gen:
#   team:('jean', 'furina', 'fischl', 'neuvillette') rot_len:17 DPS:20124 MaxHit:44337
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:14 DPS:19251 MaxHit:50994
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:14 DPS:18484 MaxHit:50700
#   team:('furina', 'jean', 'fischl', 'neuvillette') rot_len:14 DPS:17657 MaxHit:44942
#   team:('furina', 'jean', 'neuvillette', 'fischl') rot_len:13 DPS:17274 MaxHit:42903
# Gen best: team=('jean', 'furina', 'fischl', 'neuvillette') rot_len=17 DPS:20124 MaxHit:44337
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 18/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.40, rot_div=0.80, action_entropy=5.8
# Top 5 this gen:
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:14 DPS:20842 MaxHit:44160
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:14 DPS:19823 MaxHit:45029
#   team:('neuvillette', 'furina', 'fischl', 'jean') rot_len:15 DPS:18248 MaxHit:47705
#   team:('furina', 'neuvillette', 'jean', 'fischl') rot_len:13 DPS:17939 MaxHit:44641
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:15 DPS:17875 MaxHit:47752
# Gen best: team=('fischl', 'jean', 'furina', 'neuvillette') rot_len=14 DPS:20842 MaxHit:44160
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 19/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.48, rot_div=0.82, action_entropy=5.8
# Top 5 this gen:
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:13 DPS:20282 MaxHit:43779
#   team:('furina', 'neuvillette', 'jean', 'fischl') rot_len:14 DPS:18784 MaxHit:58499
#   team:('furina', 'jean', 'fischl', 'neuvillette') rot_len:14 DPS:17723 MaxHit:36592
#   team:('furina', 'jean', 'fischl', 'neuvillette') rot_len:15 DPS:16835 MaxHit:51235
#   team:('furina', 'neuvillette', 'fischl', 'jean') rot_len:14 DPS:16708 MaxHit:40118
# Gen best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=13 DPS:20282 MaxHit:43779
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 20/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.82, action_entropy=5.8
# Top 5 this gen:
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:14 DPS:19805 MaxHit:36656
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:14 DPS:19352 MaxHit:47008
#   team:('neuvillette', 'furina', 'fischl', 'jean') rot_len:13 DPS:17127 MaxHit:44985
#   team:('fischl', 'furina', 'neuvillette', 'jean') rot_len:21 DPS:17040 MaxHit:38022
#   team:('furina', 'jean', 'neuvillette', 'fischl') rot_len:16 DPS:17005 MaxHit:53091
# Gen best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=14 DPS:19805 MaxHit:36656
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 21/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.40, rot_div=0.83, action_entropy=5.8
# Top 5 this gen:
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:14 DPS:19123 MaxHit:39598
#   team:('furina', 'jean', 'fischl', 'neuvillette') rot_len:14 DPS:18322 MaxHit:47913
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:14 DPS:16577 MaxHit:31270
#   team:('furina', 'jean', 'neuvillette', 'fischl') rot_len:16 DPS:15913 MaxHit:39274
#   team:('furina', 'neuvillette', 'fischl', 'jean') rot_len:14 DPS:15872 MaxHit:38957
# Gen best: team=('fischl', 'jean', 'furina', 'neuvillette') rot_len=14 DPS:19123 MaxHit:39598
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 22/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.83, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:14 DPS:19937 MaxHit:37186
#   team:('furina', 'neuvillette', 'jean', 'fischl') rot_len:14 DPS:19910 MaxHit:50030
#   team:('jean', 'fischl', 'neuvillette', 'furina') rot_len:22 DPS:17064 MaxHit:33454
#   team:('neuvillette', 'fischl', 'furina', 'jean') rot_len:21 DPS:16706 MaxHit:57585
#   team:('furina', 'neuvillette', 'fischl', 'jean') rot_len:14 DPS:16354 MaxHit:52002
# Gen best: team=('fischl', 'jean', 'furina', 'neuvillette') rot_len=14 DPS:19937 MaxHit:37186
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 23/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.82, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:16 DPS:20043 MaxHit:50846
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:16 DPS:18669 MaxHit:35101
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:14 DPS:18459 MaxHit:46931
#   team:('jean', 'fischl', 'furina', 'neuvillette') rot_len:21 DPS:17792 MaxHit:32676
#   team:('furina', 'neuvillette', 'fischl', 'jean') rot_len:14 DPS:16895 MaxHit:54280
# Gen best: team=('fischl', 'jean', 'furina', 'neuvillette') rot_len=16 DPS:20043 MaxHit:50846
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 24/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.46, rot_div=0.84, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:17 DPS:21298 MaxHit:52168
#   team:('neuvillette', 'fischl', 'furina', 'jean') rot_len:23 DPS:20576 MaxHit:63641
#   team:('furina', 'neuvillette', 'jean', 'fischl') rot_len:16 DPS:20105 MaxHit:53941
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:15 DPS:18739 MaxHit:38141
#   team:('neuvillette', 'jean', 'furina', 'fischl') rot_len:23 DPS:18737 MaxHit:67320
# Gen best: team=('fischl', 'jean', 'furina', 'neuvillette') rot_len=17 DPS:21298 MaxHit:52168
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 25/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.38, rot_div=0.85, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:16 DPS:20973 MaxHit:37924
#   team:('neuvillette', 'jean', 'furina', 'fischl') rot_len:23 DPS:19903 MaxHit:46537
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:16 DPS:19859 MaxHit:48653
#   team:('furina', 'jean', 'fischl', 'neuvillette') rot_len:17 DPS:18544 MaxHit:51138
#   team:('neuvillette', 'jean', 'fischl', 'furina') rot_len:24 DPS:17851 MaxHit:68241
# Gen best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=16 DPS:20973 MaxHit:37924
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 26/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.42, rot_div=0.85, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:17 DPS:22045 MaxHit:50027
#   team:('neuvillette', 'jean', 'furina', 'fischl') rot_len:23 DPS:21373 MaxHit:54335
#   team:('furina', 'fischl', 'jean', 'neuvillette') rot_len:17 DPS:19540 MaxHit:48681
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:14 DPS:18802 MaxHit:49006
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:14 DPS:18419 MaxHit:40658
# Gen best: team=('fischl', 'jean', 'furina', 'neuvillette') rot_len=17 DPS:22045 MaxHit:50027
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 27/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.42, rot_div=0.86, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:17 DPS:20519 MaxHit:42767
#   team:('neuvillette', 'furina', 'jean', 'fischl') rot_len:22 DPS:19739 MaxHit:46035
#   team:('jean', 'furina', 'fischl', 'neuvillette') rot_len:17 DPS:19089 MaxHit:51473
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:15 DPS:18621 MaxHit:51284
#   team:('jean', 'neuvillette', 'fischl', 'furina') rot_len:28 DPS:18547 MaxHit:50122
# Gen best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=17 DPS:20519 MaxHit:42767
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 28/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.87, action_entropy=5.8
# Top 5 this gen:
#   team:('furina', 'neuvillette', 'jean', 'fischl') rot_len:14 DPS:19868 MaxHit:45711
#   team:('jean', 'furina', 'neuvillette', 'fischl') rot_len:15 DPS:19123 MaxHit:42831
#   team:('furina', 'fischl', 'jean', 'neuvillette') rot_len:17 DPS:19019 MaxHit:46815
#   team:('furina', 'jean', 'fischl', 'neuvillette') rot_len:22 DPS:17451 MaxHit:45315
#   team:('neuvillette', 'fischl', 'jean', 'furina') rot_len:22 DPS:17098 MaxHit:46276
# Gen best: team=('furina', 'neuvillette', 'jean', 'fischl') rot_len=14 DPS:19868 MaxHit:45711
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 29/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.42, rot_div=0.86, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:14 DPS:21503 MaxHit:51504
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:17 DPS:21236 MaxHit:56942
#   team:('fischl', 'furina', 'neuvillette', 'jean') rot_len:15 DPS:20825 MaxHit:55947
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:17 DPS:20037 MaxHit:46648
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:17 DPS:19408 MaxHit:45638
# Gen best: team=('fischl', 'neuvillette', 'jean', 'furina') rot_len=14 DPS:21503 MaxHit:51504
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 30/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.42, rot_div=0.87, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:18 DPS:19004 MaxHit:42619
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:17 DPS:18880 MaxHit:37319
#   team:('furina', 'fischl', 'jean', 'neuvillette') rot_len:17 DPS:18725 MaxHit:46613
#   team:('furina', 'jean', 'fischl', 'neuvillette') rot_len:14 DPS:18369 MaxHit:41308
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:17 DPS:18261 MaxHit:34637
# Gen best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=18 DPS:19004 MaxHit:42619
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 31/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.85, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:18 DPS:22191 MaxHit:57508
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:14 DPS:21240 MaxHit:54831
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:18 DPS:20681 MaxHit:37473
#   team:('fischl', 'furina', 'neuvillette', 'jean') rot_len:17 DPS:19365 MaxHit:40722
#   team:('furina', 'fischl', 'jean', 'neuvillette') rot_len:18 DPS:19259 MaxHit:45294
# Gen best: team=('fischl', 'furina', 'jean', 'neuvillette') rot_len=18 DPS:22191 MaxHit:57508
# Overall best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=11 DPS:22373 MaxHit:50015
#
# Generation 32/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.86, action_entropy=5.7
# Top 5 this gen:
#   team:('furina', 'fischl', 'jean', 'neuvillette') rot_len:18 DPS:23828 MaxHit:60882
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:17 DPS:21633 MaxHit:53648
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:17 DPS:20443 MaxHit:41194
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:17 DPS:20170 MaxHit:57307
#   team:('fischl', 'furina', 'neuvillette', 'jean') rot_len:17 DPS:19952 MaxHit:46544
# Gen best: team=('furina', 'fischl', 'jean', 'neuvillette') rot_len=18 DPS:23828 MaxHit:60882
# Overall best: team=('furina', 'fischl', 'jean', 'neuvillette') rot_len=18 DPS:23828 MaxHit:60882
#
# Generation 33/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.46, rot_div=0.87, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:17 DPS:20891 MaxHit:49516
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:18 DPS:20668 MaxHit:45482
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:18 DPS:20038 MaxHit:42767
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:17 DPS:19754 MaxHit:44386
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:18 DPS:19560 MaxHit:39424
# Gen best: team=('fischl', 'furina', 'jean', 'neuvillette') rot_len=17 DPS:20891 MaxHit:49516
# Overall best: team=('furina', 'fischl', 'jean', 'neuvillette') rot_len=18 DPS:23828 MaxHit:60882
#
# Generation 34/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.42, rot_div=0.87, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:19 DPS:22491 MaxHit:40714
#   team:('jean', 'furina', 'fischl', 'neuvillette') rot_len:18 DPS:20203 MaxHit:46448
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:18 DPS:19704 MaxHit:37530
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:18 DPS:19689 MaxHit:41587
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:14 DPS:19205 MaxHit:41308
# Gen best: team=('fischl', 'jean', 'furina', 'neuvillette') rot_len=19 DPS:22491 MaxHit:40714
# Overall best: team=('furina', 'fischl', 'jean', 'neuvillette') rot_len=18 DPS:23828 MaxHit:60882
#
# Generation 35/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.87, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:18 DPS:23000 MaxHit:49091
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:19 DPS:22813 MaxHit:57791
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:17 DPS:22049 MaxHit:46063
#   team:('fischl', 'furina', 'neuvillette', 'jean') rot_len:19 DPS:21155 MaxHit:44044
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:14 DPS:20781 MaxHit:57307
# Gen best: team=('fischl', 'furina', 'jean', 'neuvillette') rot_len=18 DPS:23000 MaxHit:49091
# Overall best: team=('furina', 'fischl', 'jean', 'neuvillette') rot_len=18 DPS:23828 MaxHit:60882
#
# Generation 36/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.86, action_entropy=5.7
# Top 5 this gen:
#   team:('furina', 'fischl', 'jean', 'neuvillette') rot_len:18 DPS:23363 MaxHit:64984
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:21 DPS:22172 MaxHit:42628
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:20 DPS:21937 MaxHit:54796
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:19 DPS:21438 MaxHit:50552
#   team:('furina', 'jean', 'fischl', 'neuvillette') rot_len:19 DPS:21312 MaxHit:46152
# Gen best: team=('furina', 'fischl', 'jean', 'neuvillette') rot_len=18 DPS:23363 MaxHit:64984
# Overall best: team=('furina', 'fischl', 'jean', 'neuvillette') rot_len=18 DPS:23828 MaxHit:60882
#
# Generation 37/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.87, action_entropy=5.7
# Top 5 this gen:
#   team:('jean', 'furina', 'neuvillette', 'fischl') rot_len:20 DPS:22545 MaxHit:58670
#   team:('fischl', 'furina', 'neuvillette', 'jean') rot_len:18 DPS:22545 MaxHit:51859
#   team:('furina', 'fischl', 'jean', 'neuvillette') rot_len:18 DPS:20857 MaxHit:46502
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:19 DPS:20468 MaxHit:47061
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:20 DPS:19479 MaxHit:50476
# Gen best: team=('jean', 'furina', 'neuvillette', 'fischl') rot_len=20 DPS:22545 MaxHit:58670
# Overall best: team=('furina', 'fischl', 'jean', 'neuvillette') rot_len=18 DPS:23828 MaxHit:60882
#
# Generation 38/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.48, rot_div=0.86, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'furina', 'neuvillette', 'jean') rot_len:18 DPS:21799 MaxHit:49615
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:18 DPS:21021 MaxHit:52261
#   team:('furina', 'neuvillette', 'jean', 'fischl') rot_len:19 DPS:20533 MaxHit:58790
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:18 DPS:19686 MaxHit:44892
#   team:('neuvillette', 'furina', 'jean', 'fischl') rot_len:20 DPS:19680 MaxHit:79097
# Gen best: team=('fischl', 'furina', 'neuvillette', 'jean') rot_len=18 DPS:21799 MaxHit:49615
# Overall best: team=('furina', 'fischl', 'jean', 'neuvillette') rot_len=18 DPS:23828 MaxHit:60882
#
# Generation 39/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.42, rot_div=0.86, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:20 DPS:23638 MaxHit:48168
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:18 DPS:22357 MaxHit:66498
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:18 DPS:22148 MaxHit:48045
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:18 DPS:19995 MaxHit:41519
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:18 DPS:19990 MaxHit:46716
# Gen best: team=('fischl', 'furina', 'jean', 'neuvillette') rot_len=20 DPS:23638 MaxHit:48168
# Overall best: team=('furina', 'fischl', 'jean', 'neuvillette') rot_len=18 DPS:23828 MaxHit:60882
#
# Generation 40/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.42, rot_div=0.87, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:20 DPS:24137 MaxHit:56518
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:19 DPS:20202 MaxHit:44892
#   team:('furina', 'fischl', 'jean', 'neuvillette') rot_len:18 DPS:19902 MaxHit:52616
#   team:('neuvillette', 'furina', 'jean', 'fischl') rot_len:21 DPS:19523 MaxHit:51449
#   team:('furina', 'neuvillette', 'jean', 'fischl') rot_len:20 DPS:19466 MaxHit:64378
# Gen best: team=('fischl', 'furina', 'jean', 'neuvillette') rot_len=20 DPS:24137 MaxHit:56518
# Overall best: team=('fischl', 'furina', 'jean', 'neuvillette') rot_len=20 DPS:24137 MaxHit:56518
#
# Generation 41/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.89, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:20 DPS:25457 MaxHit:44597
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:21 DPS:22737 MaxHit:49653
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:21 DPS:21996 MaxHit:50178
#   team:('neuvillette', 'fischl', 'jean', 'furina') rot_len:22 DPS:21733 MaxHit:47931
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:20 DPS:21715 MaxHit:51082
# Gen best: team=('fischl', 'furina', 'jean', 'neuvillette') rot_len=20 DPS:25457 MaxHit:44597
# Overall best: team=('fischl', 'furina', 'jean', 'neuvillette') rot_len=20 DPS:25457 MaxHit:44597
#
# Generation 42/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.89, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:20 DPS:25927 MaxHit:57896
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:19 DPS:25695 MaxHit:65376
#   team:('jean', 'neuvillette', 'fischl', 'furina') rot_len:19 DPS:25084 MaxHit:64280
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:21 DPS:21680 MaxHit:47957
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:22 DPS:20507 MaxHit:49499
# Gen best: team=('fischl', 'neuvillette', 'jean', 'furina') rot_len=20 DPS:25927 MaxHit:57896
# Overall best: team=('fischl', 'neuvillette', 'jean', 'furina') rot_len=20 DPS:25927 MaxHit:57896
#
# Generation 43/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.88, action_entropy=5.7
# Top 5 this gen:
#   team:('jean', 'neuvillette', 'fischl', 'furina') rot_len:19 DPS:24392 MaxHit:59262
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:22 DPS:23398 MaxHit:43938
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:22 DPS:22362 MaxHit:39517
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:21 DPS:21565 MaxHit:40554
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:20 DPS:21363 MaxHit:48786
# Gen best: team=('jean', 'neuvillette', 'fischl', 'furina') rot_len=19 DPS:24392 MaxHit:59262
# Overall best: team=('fischl', 'neuvillette', 'jean', 'furina') rot_len=20 DPS:25927 MaxHit:57896
#
# Generation 44/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.42, rot_div=0.89, action_entropy=5.8
# Top 5 this gen:
#   team:('fischl', 'furina', 'neuvillette', 'jean') rot_len:23 DPS:23775 MaxHit:64972
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:20 DPS:22111 MaxHit:44176
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:21 DPS:21506 MaxHit:40418
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:22 DPS:19906 MaxHit:36966
#   team:('neuvillette', 'furina', 'fischl', 'jean') rot_len:19 DPS:19783 MaxHit:44722
# Gen best: team=('fischl', 'furina', 'neuvillette', 'jean') rot_len=23 DPS:23775 MaxHit:64972
# Overall best: team=('fischl', 'neuvillette', 'jean', 'furina') rot_len=20 DPS:25927 MaxHit:57896
#
# Generation 45/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.36, rot_div=0.86, action_entropy=5.8
# Top 5 this gen:
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:22 DPS:25796 MaxHit:70671
#   team:('fischl', 'furina', 'neuvillette', 'jean') rot_len:22 DPS:24107 MaxHit:53445
#   team:('neuvillette', 'jean', 'furina', 'fischl') rot_len:22 DPS:21439 MaxHit:49488
#   team:('jean', 'fischl', 'furina', 'neuvillette') rot_len:19 DPS:21171 MaxHit:51054
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:22 DPS:20498 MaxHit:42652
# Gen best: team=('fischl', 'jean', 'furina', 'neuvillette') rot_len=22 DPS:25796 MaxHit:70671
# Overall best: team=('fischl', 'neuvillette', 'jean', 'furina') rot_len=20 DPS:25927 MaxHit:57896
#
# Generation 46/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.42, rot_div=0.85, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:22 DPS:23520 MaxHit:47061
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:22 DPS:22551 MaxHit:37933
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:24 DPS:20712 MaxHit:35220
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:23 DPS:19232 MaxHit:43413
#   team:('jean', 'neuvillette', 'furina', 'fischl') rot_len:22 DPS:19057 MaxHit:65851
# Gen best: team=('fischl', 'jean', 'furina', 'neuvillette') rot_len=22 DPS:23520 MaxHit:47061
# Overall best: team=('fischl', 'neuvillette', 'jean', 'furina') rot_len=20 DPS:25927 MaxHit:57896
#
# Generation 47/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.85, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:22 DPS:21485 MaxHit:37938
#   team:('neuvillette', 'jean', 'fischl', 'furina') rot_len:24 DPS:21435 MaxHit:50731
#   team:('neuvillette', 'fischl', 'jean', 'furina') rot_len:24 DPS:21142 MaxHit:48349
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:21 DPS:21124 MaxHit:49833
#   team:('furina', 'fischl', 'jean', 'neuvillette') rot_len:24 DPS:20706 MaxHit:50761
# Gen best: team=('fischl', 'neuvillette', 'jean', 'furina') rot_len=22 DPS:21485 MaxHit:37938
# Overall best: team=('fischl', 'neuvillette', 'jean', 'furina') rot_len=20 DPS:25927 MaxHit:57896
#
# Generation 48/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.87, action_entropy=5.7
# Top 5 this gen:
#   team:('neuvillette', 'fischl', 'furina', 'jean') rot_len:22 DPS:23123 MaxHit:59581
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:21 DPS:22575 MaxHit:41619
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:24 DPS:21189 MaxHit:60655
#   team:('furina', 'jean', 'neuvillette', 'fischl') rot_len:21 DPS:20884 MaxHit:42653
#   team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:24 DPS:20342 MaxHit:49195
# Gen best: team=('neuvillette', 'fischl', 'furina', 'jean') rot_len=22 DPS:23123 MaxHit:59581
# Overall best: team=('fischl', 'neuvillette', 'jean', 'furina') rot_len=20 DPS:25927 MaxHit:57896
#
# Generation 49/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.40, rot_div=0.86, action_entropy=5.8
# Top 5 this gen:
#   team:('fischl', 'jean', 'neuvillette', 'furina') rot_len:24 DPS:24789 MaxHit:46426
#   team:('neuvillette', 'furina', 'jean', 'fischl') rot_len:24 DPS:22991 MaxHit:63410
#   team:('fischl', 'neuvillette', 'furina', 'jean') rot_len:21 DPS:22086 MaxHit:52190
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:25 DPS:20170 MaxHit:53059
#   team:('furina', 'neuvillette', 'jean', 'fischl') rot_len:21 DPS:20110 MaxHit:44408
# Gen best: team=('fischl', 'jean', 'neuvillette', 'furina') rot_len=24 DPS:24789 MaxHit:46426
# Overall best: team=('fischl', 'neuvillette', 'jean', 'furina') rot_len=20 DPS:25927 MaxHit:57896
#
# Generation 50/50
# Unique individuals: 50/50
# Diversity: team_uniq=0.44, rot_div=0.87, action_entropy=5.7
# Top 5 this gen:
#   team:('fischl', 'furina', 'jean', 'neuvillette') rot_len:24 DPS:25121 MaxHit:50489
#   team:('fischl', 'furina', 'neuvillette', 'jean') rot_len:21 DPS:21223 MaxHit:36592
#   team:('neuvillette', 'fischl', 'jean', 'furina') rot_len:25 DPS:20677 MaxHit:47133
#   team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:21 DPS:18701 MaxHit:46177
#   team:('jean', 'furina', 'neuvillette', 'fischl') rot_len:23 DPS:18617 MaxHit:50726
# Gen best: team=('fischl', 'furina', 'jean', 'neuvillette') rot_len=24 DPS:25121 MaxHit:50489
# Overall best: team=('fischl', 'neuvillette', 'jean', 'furina') rot_len=20 DPS:25927 MaxHit:57896
#
# ===== FINAL BEST TEAM (by DPS) =====
# DPS: 25927  MaxHit: 57896
#
# options iteration=1 duration=100 swap_delay=4;
# target lvl=100 resist=0.1 particle_threshold=250000 particle_drop_count=1;
#
# fischl char lvl=70/90 cons=6 talent=1,7,7 +params=[start_energy=100];
# fischl add weapon="thestringless" refine=2 lvl=90/90;
# fischl add set="goldentroupe" count=4;
# fischl add stats atk=359.0000 atk%=0.5590 cd=0.3110 cr=0.4700 def=116.0000 def%=0.1090 electro%=0.4660 em=114.0000 er=0.1160 hp=6059.0000 hp%=0.0530;
# neuvillette char lvl=90/90 cons=0 talent=8,6,7 +params=[start_energy=100];
# neuvillette add weapon="prototypeamber" refine=1 lvl=90/90;
# neuvillette add set="marechausseehunter" count=4;
# neuvillette add stats atk=325.0000 atk%=0.0820 cd=0.9560 cr=0.2800 def=42.0000 def%=0.1020 em=196.0000 hp=5886.0000 hp%=0.9210 hydro%=0.4660;
# jean char lvl=70/90 cons=1 talent=1,1,6 +params=[start_energy=100];
# jean add weapon="amenomakageuchi" refine=1 lvl=80/90;
# jean add set="viridescentvenerer" count=4;
# jean add stats atk=375.0000 atk%=0.9580 cd=0.3500 cr=0.4740 def=97.0000 def%=0.1600 em=114.0000 er=0.3040 hp=4266.0000 hp%=0.0530;
# furina char lvl=90/90 cons=0 talent=1,8,8 +params=[start_energy=100];
# furina add weapon="fleuvecendreferryman" refine=3 lvl=80/90;
# furina add set="goldentroupe" count=4;
# furina add stats atk=392.0000 cd=1.0500 cr=0.3220 def=39.0000 def%=0.1670 em=113.0000 er=0.1490 hp=5079.0000 hp%=1.0660;
# active fischl;
#
# while 1 {
#   fischl skill;
#   if .jean.skill.ready { jean skill; }
#   if .fischl.skill.ready { fischl skill; }
#   neuvillette skill;
#   fischl attack:2;
#   if .furina.skill.ready { furina skill; }
#   jean attack:5;
#   if .jean.energy >= 70 { jean burst; }
#   fischl attack:4;
#   if .fischl.skill.ready { fischl skill; }
#   if .jean.skill.ready { jean skill; }
#   if .furina.energy >= 60 { furina burst; }
#   fischl burst;
#   if .neuvillette.skill.ready { neuvillette skill; }
#   if .fischl.skill.ready { fischl skill; }
#   jean skill;
#   jean attack:1;
#   fischl attack:1;
#   if .jean.energy >= 70 { jean burst; }
#   if .fischl.energy >= 70 { fischl burst; }
# }
#
#
# ===== PARETO FRONT (top 10) =====
# #1 team:('fischl', 'neuvillette', 'jean', 'furina') rot_len:20
#    DPS:25927  MaxHit:57896  SD:0
# #2 team:('fischl', 'jean', 'furina', 'neuvillette') rot_len:22
#    DPS:25796  MaxHit:70671  SD:0
# #3 team:('neuvillette', 'fischl', 'furina', 'jean') rot_len:22
#    DPS:20021  MaxHit:76524  SD:0
# #4 team:('neuvillette', 'fischl', 'jean', 'furina') rot_len:20
#    DPS:19686  MaxHit:77044  SD:0
# #5 team:('neuvillette', 'furina', 'jean', 'fischl') rot_len:20
#    DPS:19680  MaxHit:79097  SD:0
# #6 team:('furina', 'jean', 'neuvillette', 'fischl') rot_len:9
#    DPS:10691  MaxHit:80516  SD:0
# #7 team:('furina', 'jean', 'neuvillette', 'fischl') rot_len:9
#    DPS:7875  MaxHit:84527  SD:0
